# %% [markdown]
# # Phase 2 Milestone 1

# %% [markdown]
# ### Muhammad Galang Al-Hakim

# %% [markdown]
# ### HCK-004

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

#untuk model
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model, load_model
# from tensorflow.python.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Input, Dense, Dropout

from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
# %matplotlib inline
import tensorflow as tf
# !pip install feature-engine
from feature_engine.outliers import Winsorizer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras import regularizers
#preprocessing
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.compose import ColumnTransformer

#evaluasi
from sklearn.metrics import confusion_matrix ,accuracy_score, roc_curve,roc_auc_score,precision_score, recall_score, classification_report, f1_score

import pickle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: feature-engine in /usr/local/lib/python3.9/dist-packages (1.6.0)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from feature-engine) (0.13.5)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.9/dist-packages (from feature-engine) (1.22.4)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.9/dist-packages (from feature-engine) (1.4.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from feature-engine) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from feature-engine) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.3->feature-engine) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.3->feature-engine) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0.0->feature-engine) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0.0->feature-engine) (1.1.1)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.11.1->feature-engine) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.11.1->feature-engine) (23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels>=0.11.1->feature-engine) (1.16.0)

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv('/content/churn.txt')
df
# Out:
#                 user_id  age gender region_category membership_category  \
# 0      9f420209e7d129f3   29      F             NaN       No Membership
# 1      ac6e97806267549e   50      M             NaN    Basic Membership
# 2      a6aa19b1580eed4e   26      F            City   Silver Membership
# 3      aeee343277211c2f   63      F         Village       No Membership
# 4      82448b5c8ce6390c   64      M            Town   Silver Membership
# ...                 ...  ...    ...             ...                 ...
# 37005  924e9c06f0c73817   36      M            Town     Gold Membership
# 37006  90e22286ac0acf04   27      F            City     Gold Membership
# 37007  9329a6297407334a   20      M             NaN     Gold Membership
# 37008  a4403ddda8fcf9f3   38      F            City     Gold Membership
# 37009  93b5d0330d24fa15   36      M            Town     Gold Membership
#
#       joining_date joined_through_referral     preferred_offer_types  \
# 0       2017-04-05                     Yes            Without Offers
# 1       2017-03-31                     Yes            Without Offers
# 2       2017-02-11                     NaN  Credit/Debit Card Offers
# 3       2015-12-23                      No  Credit/Debit Card Offers
# 4       2015-03-20                     NaN     Gift Vouchers/Coupons
# ...            ...                     ...                       ...
# 37005   2015-03-05                     NaN  Credit/Debit Card Offers
# 37006   2017-01-15                     Yes            Without Offers
# 37007   2015-07-11                     Yes            Without Offers
# 37008   2016-05-25                     Yes            Without Offers
# 37009   2016-10-18                     NaN            Without Offers
#
#       medium_of_operation internet_option  ... avg_time_spent  \
# 0                     NaN           Wi-Fi  ...    1184.490000
# 1                 Desktop     Fiber_Optic  ...     338.150000
# 2                     NaN     Fiber_Optic  ...     235.140000
# 3                 Desktop     Fiber_Optic  ...      56.670000
# 4              Smartphone           Wi-Fi  ...     153.990000
# ...                   ...             ...  ...            ...
# 37005                 NaN     Fiber_Optic  ...     199.330000
# 37006             Desktop           Wi-Fi  ...     368.500000
# 37007                 NaN     Mobile_Data  ...     272.130000
# 37008             Desktop           Wi-Fi  ...      65.070000
# 37009                Both     Fiber_Optic  ...     972.776679
#
#        avg_transaction_value  avg_frequency_login_days  points_in_wallet  \
# 0                   38604.69                      10.0            627.48
# 1                    7665.66                      17.0            575.97
# 2                   37671.69                       5.0            767.93
# 3                   15678.14                      11.0            590.22
# 4                    8422.68                       0.0            722.04
# ...                      ...                       ...               ...
# 37005               29455.29                       9.0            846.52
# 37006               27038.47                       8.0            835.98
# 37007               39305.35                      27.0            714.90
# 37008               46108.73                       6.0            744.99
# 37009               26905.49                      22.0            700.93
#
#        used_special_discount  offer_application_preference past_complaint  \
# 0                        Yes                           Yes            Yes
# 1                        Yes                            No            Yes
# 2                        Yes                            No            Yes
# 3                         No                           Yes             No
# 4                        Yes                            No             No
# ...                      ...                           ...            ...
# 37005                    Yes                           Yes             No
# 37006                     No                           Yes             No
# 37007                    Yes                           Yes            Yes
# 37008                     No                           Yes             No
# 37009                    Yes                            No            Yes
#
#                complaint_status               feedback churn_risk_score
# 0      No Information Available           Poor Website                1
# 1      No Information Available  Poor Customer Service                1
# 2      No Information Available           Too many ads                0
# 3                Not Applicable           Too many ads                1
# 4                Not Applicable   Poor Product Quality                0
# ...                         ...                    ...              ...
# 37005            Not Applicable  User Friendly Website                0
# 37006            Not Applicable       Reasonable Price                0
# 37007                    Solved  Poor Customer Service                0
# 37008            Not Applicable           Poor Website                0
# 37009  No Information Available  Poor Customer Service                1
#
# [37010 rows x 22 columns]

# %% [markdown]
# ### Dataset Description

# %% [markdown]
# - **user_id** = ID of a customer
# - **age** = Age of a customer
# - **gender** = Gender of a customer
# - **region_category** = Region that a customer belongs to
# - **membership_category** = Category of the membership that a customer is using
# - **joining_date** = Date when a customer became a member
# - **joined_through referral**	= Whether a customer joined using any referral code or ID
# - **preferred_offer types** = Type of offer that a customer prefers
# - **medium_of operation** = Medium of operation that a customer uses for transactions
# - **internet_option** = Type of internet service a customer uses
# - **last_visit_time** = The last time a customer visited the website
# - **days_since_last_login** = Number of days since a customer last logged into the website
# - **avg_time_spent** = Average time spent by a customer on the website
# - **avg_transaction_value** = Average transaction value of a customer
# - **avg_frequency_login_days** = Number of times a customer has logged in to the website
# - **points_in_wallet** = Points awarded to a customer on each transaction
# - **used_special_discount** = Whether a customer uses special discounts offered
# - **offer_application_preference**	=  Whether a customer prefers offers
# - **past_complaint** = Whether a customer has raised any complaints
# - **complaint_status** = Whether the complaints raised by a customer was resolved
# - **feedback** = Feedback provided by a customer
# - **churn_risk_score** = Churn score 0 : Not churn, 1 : Churn

# %%
df.head(10)
# Out:
#             user_id  age gender region_category  membership_category  \
# 0  9f420209e7d129f3   29      F             NaN        No Membership
# 1  ac6e97806267549e   50      M             NaN     Basic Membership
# 2  a6aa19b1580eed4e   26      F            City    Silver Membership
# 3  aeee343277211c2f   63      F         Village        No Membership
# 4  82448b5c8ce6390c   64      M            Town    Silver Membership
# 5  96fbb6f63244b1f4   35      M            Town   Premium Membership
# 6  a52bc51378ecb057   43      M             NaN      Gold Membership
# 7  94f338d20bf0f2b2   15      M            City        No Membership
# 8  85c7996b17862e57   49      M            Town  Platinum Membership
# 9  8a1625846d7a198b   35      F            Town     Basic Membership
#
#   joining_date joined_through_referral     preferred_offer_types  \
# 0   2017-04-05                     Yes            Without Offers
# 1   2017-03-31                     Yes            Without Offers
# 2   2017-02-11                     NaN  Credit/Debit Card Offers
# 3   2015-12-23                      No  Credit/Debit Card Offers
# 4   2015-03-20                     NaN     Gift Vouchers/Coupons
# 5   2016-08-16                      No  Credit/Debit Card Offers
# 6   2017-03-09                     Yes     Gift Vouchers/Coupons
# 7   2016-09-11                      No  Credit/Debit Card Offers
# 8   2017-04-24                     Yes            Without Offers
# 9   2016-12-01                     Yes  Credit/Debit Card Offers
#
#   medium_of_operation internet_option  ... avg_time_spent  \
# 0                 NaN           Wi-Fi  ...    1184.490000
# 1             Desktop     Fiber_Optic  ...     338.150000
# 2                 NaN     Fiber_Optic  ...     235.140000
# 3             Desktop     Fiber_Optic  ...      56.670000
# 4          Smartphone           Wi-Fi  ...     153.990000
# 5                 NaN           Wi-Fi  ...    1397.318999
# 6          Smartphone     Mobile_Data  ...     416.300000
# 7          Smartphone           Wi-Fi  ...      34.070000
# 8                 NaN     Fiber_Optic  ...     650.120000
# 9             Desktop     Mobile_Data  ...     106.230000
#
#    avg_transaction_value  avg_frequency_login_days  points_in_wallet  \
# 0               38604.69                      10.0         627.48000
# 1                7665.66                      17.0         575.97000
# 2               37671.69                       5.0         767.93000
# 3               15678.14                      11.0         590.22000
# 4                8422.68                       0.0         722.04000
# 5               29664.01                      28.0         782.49000
# 6               13160.39                      24.0         712.94000
# 7                9151.14                      29.0         655.43000
# 8               81628.48                      11.0           0.00000
# 9               28232.59                      16.0         984.93392
#
#    used_special_discount  offer_application_preference past_complaint  \
# 0                    Yes                           Yes            Yes
# 1                    Yes                            No            Yes
# 2                    Yes                            No            Yes
# 3                     No                           Yes             No
# 4                    Yes                            No             No
# 5                     No                           Yes            Yes
# 6                    Yes                            No             No
# 7                    Yes                            No             No
# 8                    Yes                           Yes             No
# 9                     No                           Yes             No
#
#            complaint_status                  feedback churn_risk_score
# 0  No Information Available              Poor Website                1
# 1  No Information Available     Poor Customer Service                1
# 2  No Information Available              Too many ads                0
# 3            Not Applicable              Too many ads                1
# 4            Not Applicable      Poor Product Quality                0
# 5                  Unsolved      Poor Product Quality                0
# 6            Not Applicable       No reason specified                1
# 7            Not Applicable       No reason specified                1
# 8            Not Applicable  Products always in Stock                0
# 9            Not Applicable              Too many ads                1
#
# [10 rows x 22 columns]

# %%
df.tail(10)
# Out:
#                 user_id  age gender region_category membership_category  \
# 37000  8a0fff47b7846031   25      F            Town       No Membership
# 37001  8832eec42dc0e347   38      M            Town   Silver Membership
# 37002  b9d9761f4d367c7a   49      F            City       No Membership
# 37003  a38816e7522f5f7b   42      F            Town    Basic Membership
# 37004  8968d0458164dda9   19      F            Town     Gold Membership
# 37005  924e9c06f0c73817   36      M            Town     Gold Membership
# 37006  90e22286ac0acf04   27      F            City     Gold Membership
# 37007  9329a6297407334a   20      M             NaN     Gold Membership
# 37008  a4403ddda8fcf9f3   38      F            City     Gold Membership
# 37009  93b5d0330d24fa15   36      M            Town     Gold Membership
#
#       joining_date joined_through_referral     preferred_offer_types  \
# 37000   2017-01-20                      No     Gift Vouchers/Coupons
# 37001   2016-09-19                     NaN  Credit/Debit Card Offers
# 37002   2017-12-12                     NaN            Without Offers
# 37003   2017-07-05                     Yes     Gift Vouchers/Coupons
# 37004   2016-07-17                     Yes            Without Offers
# 37005   2015-03-05                     NaN  Credit/Debit Card Offers
# 37006   2017-01-15                     Yes            Without Offers
# 37007   2015-07-11                     Yes            Without Offers
# 37008   2016-05-25                     Yes            Without Offers
# 37009   2016-10-18                     NaN            Without Offers
#
#       medium_of_operation internet_option  ... avg_time_spent  \
# 37000          Smartphone           Wi-Fi  ...     119.830000
# 37001          Smartphone           Wi-Fi  ...      34.790000
# 37002                Both           Wi-Fi  ...     499.510000
# 37003                Both           Wi-Fi  ...     529.580000
# 37004          Smartphone     Fiber_Optic  ...     119.960000
# 37005                 NaN     Fiber_Optic  ...     199.330000
# 37006             Desktop           Wi-Fi  ...     368.500000
# 37007                 NaN     Mobile_Data  ...     272.130000
# 37008             Desktop           Wi-Fi  ...      65.070000
# 37009                Both     Fiber_Optic  ...     972.776679
#
#        avg_transaction_value  avg_frequency_login_days  points_in_wallet  \
# 37000               13147.91                       0.0       1019.382051
# 37001               30820.83                      23.0        631.830000
# 37002               17110.71                      24.0        587.010000
# 37003               42964.11                      18.0        619.280000
# 37004               14218.43                       7.0        781.840000
# 37005               29455.29                       9.0        846.520000
# 37006               27038.47                       8.0        835.980000
# 37007               39305.35                      27.0        714.900000
# 37008               46108.73                       6.0        744.990000
# 37009               26905.49                      22.0        700.930000
#
#        used_special_discount  offer_application_preference past_complaint  \
# 37000                    Yes                            No            Yes
# 37001                    Yes                            No            Yes
# 37002                    Yes                            No             No
# 37003                    Yes                           Yes             No
# 37004                    Yes                            No             No
# 37005                    Yes                           Yes             No
# 37006                     No                           Yes             No
# 37007                    Yes                           Yes            Yes
# 37008                     No                           Yes             No
# 37009                    Yes                            No            Yes
#
#                complaint_status               feedback churn_risk_score
# 37000       Solved in Follow-up   Poor Product Quality                1
# 37001                  Unsolved  Poor Customer Service                1
# 37002            Not Applicable  Poor Customer Service                1
# 37003            Not Applicable   Poor Product Quality                1
# 37004            Not Applicable           Too many ads                0
# 37005            Not Applicable  User Friendly Website                0
# 37006            Not Applicable       Reasonable Price                0
# 37007                    Solved  Poor Customer Service                0
# 37008            Not Applicable           Poor Website                0
# 37009  No Information Available  Poor Customer Service                1
#
# [10 rows x 22 columns]

# %% [markdown]
# # Exploration Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37010 entries, 0 to 37009
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   user_id                       37010 non-null  object
#  1   age                           37010 non-null  int64
#  2   gender                        36951 non-null  object
#  3   region_category               31579 non-null  object
#  4   membership_category           37010 non-null  object
#  5   joining_date                  37010 non-null  object
#  6   joined_through_referral       31568 non-null  object
#  7   preferred_offer_types         36722 non-null  object
#  8   medium_of_operation           31615 non-null  object
#  9   internet_option               37010 non-null  object
#  10  last_visit_time               37010 non-null  object
#  11  days_since_last_login         37010 non-null  int64
#  12  avg_time_spent                37010 non-null  float64
#  13  avg_transaction_value         37010 non-null  float64
#  14  avg_frequency_login_days      37010 non-null  float64
#  15  points_in_wallet              37010 non-null  float64
#  16  used_special_discount         37010 non-null  object
#  17  offer_application_preference  37010 non-null  object
#  18  past_complaint                37010 non-null  object
#  19  complaint_status              37010 non-null  object
#  20  feedback                      37010 non-null  object
#  21  churn_risk_score              37010 non-null  int64
# dtypes: float64(4), int64(3), object(15)
# memory usage: 6.2+ MB

# %%
df.describe()
# Out:
#                 age  days_since_last_login  avg_time_spent  \
# count  37010.000000           37010.000000    37010.000000
# mean      37.120697             -41.943502      279.201356
# std       15.866834             228.875324      330.017336
# min       10.000000            -999.000000        0.000000
# 25%       23.000000               8.000000       60.122500
# 50%       37.000000              12.000000      161.770000
# 75%       51.000000              16.000000      356.525000
# max       64.000000              26.000000     3235.578521
#
#        avg_transaction_value  avg_frequency_login_days  points_in_wallet  \
# count           37010.000000              37010.000000      37010.000000
# mean            29272.430216                 14.659540        623.590885
# std             19445.963492                  9.478756        270.218956
# min               800.460000                  0.000000          0.000000
# 25%             14177.835000                  7.000000        574.220000
# 50%             27554.485000                 14.000000        680.400000
# 75%             40858.672500                 22.000000        756.990000
# max             99914.050000                 73.061995       2069.069761
#
#        churn_risk_score
# count      37010.000000
# mean           0.540881
# std            0.498333
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            1.000000
# max            1.000000

# %%
df.isnull().sum()
# Out:
# user_id                            0
# age                                0
# gender                            59
# region_category                 5431
# membership_category                0
# joining_date                       0
# joined_through_referral         5442
# preferred_offer_types            288
# medium_of_operation             5395
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                   0
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# churn_risk_score                   0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 37005    False
# 37006    False
# 37007    False
# 37008    False
# 37009    False
# Length: 37010, dtype: bool

# %%
df.hist(bins=20, figsize=(15, 10))
plt.show()

# %%
for column in df.columns:
    print(f"Number of unique values in {column}: {df[column].nunique()}")
# Out:
# Number of unique values in user_id: 36992
# Number of unique values in age: 55
# Number of unique values in gender: 2
# Number of unique values in region_category: 3
# Number of unique values in membership_category: 6
# Number of unique values in joining_date: 1096
# Number of unique values in joined_through_referral: 2
# Number of unique values in preferred_offer_types: 3
# Number of unique values in medium_of_operation: 3
# Number of unique values in internet_option: 3
# Number of unique values in last_visit_time: 30101
# Number of unique values in days_since_last_login: 27
# Number of unique values in avg_time_spent: 24243
# Number of unique values in avg_transaction_value: 36894
# Number of unique values in avg_frequency_login_days: 971
# Number of unique values in points_in_wallet: 23564
# Number of unique values in used_special_discount: 2
# Number of unique values in offer_application_preference: 2
# Number of unique values in past_complaint: 2
# Number of unique values in complaint_status: 5
# Number of unique values in feedback: 9
# Number of unique values in churn_risk_score: 2

# %%
plt.hist(df['age'], bins=10)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(data=df, x='churn_risk_score')
plt.show()

# %%
plt.scatter(df['avg_time_spent'], df['avg_transaction_value'], c=df['churn_risk_score'])
plt.xlabel('Average time spent')
plt.ylabel('Average transaction value')
plt.colorbar()
plt.show()

# %%
sns.boxplot(data=df, x='churn_risk_score', y='points_in_wallet')
plt.show()

# %%
sns.boxplot(data=df, x='churn_risk_score', y='age')
plt.show()

# %%
sns.boxplot(data=df, x='churn_risk_score', y='avg_frequency_login_days')
plt.show()

# %%
sns.countplot(data=df, x='region_category')
plt.show()

# %%
sns.countplot(data=df, x='membership_category')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
num_col = ['age','days_since_last_login','avg_time_spent','avg_transaction_value','avg_frequency_login_days']
cat_col_ohe = ['region_category','preferred_offer_types','medium_of_operation','internet_option','complaint_status','feedback']
cat_col_ord = ['gender','membership_category','joined_through_referral','used_special_discount','offer_application_preference','past_complaint']

# %%
fitur= df.drop('churn_risk_score',axis=1)
target= df['churn_risk_score']

# %%
x_train_full, x_test, y_train_full, y_test= train_test_split(
    fitur, target, test_size= 0.2, stratify=target)

# %%
x_train_full, x_test,  y_train_full, y_test = train_test_split(fitur,
                                                                target,
                                                                shuffle=True, test_size=0.2,
                                                                stratify= target
                                                                )

x_train, x_val, y_train, y_val = train_test_split(x_train_full,
                                                   y_train_full,
                                                   shuffle=True, test_size=0.2, stratify= y_train_full)

# %%
x_train.skew()
# Out:
# <ipython-input-26-6ed0439853c6>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   x_train.skew()
# age                        -0.014227
# days_since_last_login      -3.939538
# avg_time_spent              2.257475
# avg_transaction_value       1.000870
# avg_frequency_login_days    0.387154
# points_in_wallet           -0.786240
# dtype: float64

# %%
num_transformer = Pipeline([
        ('outlier', Winsorizer(capping_method='gaussian', tail='both', fold=3)),
        ('scaler', StandardScaler())
    ])
num_ss = num_transformer.fit_transform(x_train[['age','avg_frequency_login_days']])

# %%
num_transformer2 = Pipeline([
        ('outlier', Winsorizer(capping_method='iqr', tail='both', fold=1.5)),
        ('scaler', MinMaxScaler())
    ])
num_mm = num_transformer2.fit_transform(x_train[['points_in_wallet']])

# %%
num_transformer3 = Pipeline([
        ('outlier', Winsorizer(capping_method='iqr', tail='both', fold=3)),
        ('scaler', MinMaxScaler())
    ])
num_mm2 = num_transformer3.fit_transform(x_train[['avg_time_spent','avg_transaction_value', 'days_since_last_login']])

# %%
cat_transformer = Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('ord_enc', OrdinalEncoder(categories=[['M', 'F'], ['No Membership', 'Basic Membership', 'Silver Membership', 'Premium Membership', 'Gold Membership', 'Platinum Membership'], ['No', 'Yes'], ['No', 'Yes'], ['No', 'Yes'], ['No', 'Yes']]))
])

# %%
cat_transformer2= Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('ohe_enc', OneHotEncoder(sparse=False))
])

# %%
full_pipeline = ColumnTransformer([
        ("num1", num_transformer, ['age','avg_frequency_login_days']),
        ("num2", num_transformer2, ['points_in_wallet']),
        ("num3", num_transformer3, ['avg_time_spent','avg_transaction_value', 'days_since_last_login']),
        ("cat_ord", cat_transformer, ['gender', 'membership_category','joined_through_referral','used_special_discount','offer_application_preference','past_complaint']),
        ("cat_ohe", cat_transformer2, ['region_category','preferred_offer_types','medium_of_operation','internet_option','complaint_status','feedback']),
    ])

# %%
X_train= full_pipeline.fit_transform(x_train_full)
X_test= full_pipeline.transform(x_test)
X_val = full_pipeline.transform(x_val)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # Model Definition

# %%
X_train.shape[1:]
# Out:
# (38,)

# %%
X_train
# Out:
# array([[-1.27244331,  0.79282794,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.5665681 ,  1.43731246,  0.45026075, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.14626503, -0.06648474,  0.09727841, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.6833201 ,  1.22248429,  0.60379062, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.38919532, -0.92579742,  0.59381296, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.45228446,  0.79282794,  0.28298418, ...,  0.        ,
#          0.        ,  0.        ]])

# %% [markdown]
# # Model Sequential

# %%
ann = Sequential()
# ann.add(tf.keras.Input(shape=(X_train.shape[1:])))
ann.add(Dense(units=30, activation='relu',input_shape=(X_train.shape[1:])))
ann.add(Dense(units=1,activation='sigmoid')) #sesuaikan dengan target atau jumlah class

ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
callbacks1= [
    EarlyStopping(monitor='val_loss', patience= 3, restore_best_weights=True),
    ModelCheckpoint('model_best.hdf5', monitor='val_loss', save_best_only=True)
]

# %%
hidden1 = ann.layers[1]
hidden1.name
# Out:
# 'dense_1'

# %%
weights, biases = hidden1.get_weights()
# weights

# %%
ann.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                1170
#
#  dense_1 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 1,201
# Trainable params: 1,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(ann, show_shapes=True)

# %%
X_train.shape
# Out:
# (29608, 38)

# %% [markdown]
# # Model Training

# %%
# Set random seed
tf.random.set_seed(42)

# 1. Create the model 
model = tf.keras.Sequential([
  tf.keras.layers.Dense(100), # add 100 dense neurons
  tf.keras.layers.Dense(10), # add another layer with 10 neurons
  tf.keras.layers.Dense(1)
])

# 2. Compile the model
model.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Adam(), # use Adam
                metrics=['accuracy'])

# 3. Fit the model
history = model.fit(X_train, y_train_full, epochs=50, verbose=1, batch_size=32, validation_data=(X_val,y_val)) # fit for 50 passes of the data
# Out:
# Epoch 1/50
# 926/926 [==============================] - 10s 4ms/step - loss: 1.8722 - accuracy: 0.7566 - val_loss: 2.3092 - val_accuracy: 0.7494
# Epoch 2/50
# 926/926 [==============================] - 4s 5ms/step - loss: 2.3679 - accuracy: 0.7560 - val_loss: 1.2834 - val_accuracy: 0.8286
# Epoch 3/50
# 926/926 [==============================] - 4s 4ms/step - loss: 1.2478 - accuracy: 0.7831 - val_loss: 0.4592 - val_accuracy: 0.7943
# Epoch 4/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4885 - accuracy: 0.7942 - val_loss: 0.3955 - val_accuracy: 0.8232
# Epoch 5/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4873 - accuracy: 0.8069 - val_loss: 0.7626 - val_accuracy: 0.6949
# Epoch 6/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.5226 - accuracy: 0.7601 - val_loss: 0.4166 - val_accuracy: 0.8166
# Epoch 7/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4685 - accuracy: 0.7972 - val_loss: 0.4021 - val_accuracy: 0.8198
# Epoch 8/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3919 - accuracy: 0.8271 - val_loss: 0.3833 - val_accuracy: 0.8224
# Epoch 9/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4012 - accuracy: 0.8289 - val_loss: 0.3952 - val_accuracy: 0.8345
# Epoch 10/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4416 - accuracy: 0.8171 - val_loss: 0.3747 - val_accuracy: 0.8328
# Epoch 11/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4025 - accuracy: 0.8313 - val_loss: 0.3945 - val_accuracy: 0.8416
# Epoch 12/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4013 - accuracy: 0.8322 - val_loss: 0.4111 - val_accuracy: 0.8247
# Epoch 13/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3988 - accuracy: 0.8289 - val_loss: 0.3996 - val_accuracy: 0.8340
# Epoch 14/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4026 - accuracy: 0.8279 - val_loss: 0.3948 - val_accuracy: 0.8391
# Epoch 15/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4060 - accuracy: 0.8301 - val_loss: 0.4000 - val_accuracy: 0.8338
# Epoch 16/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.4204 - accuracy: 0.8119 - val_loss: 0.4110 - val_accuracy: 0.8335
# Epoch 17/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4007 - accuracy: 0.8305 - val_loss: 0.3975 - val_accuracy: 0.8178
# Epoch 18/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4001 - accuracy: 0.8264 - val_loss: 0.3941 - val_accuracy: 0.8365
# Epoch 19/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.4054 - accuracy: 0.8317 - val_loss: 0.3966 - val_accuracy: 0.8354
# Epoch 20/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4202 - accuracy: 0.8272 - val_loss: 0.3831 - val_accuracy: 0.8323
# Epoch 21/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4073 - accuracy: 0.8286 - val_loss: 0.3972 - val_accuracy: 0.8364
# Epoch 22/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4035 - accuracy: 0.8309 - val_loss: 0.4102 - val_accuracy: 0.8313
# Epoch 23/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4404 - accuracy: 0.8182 - val_loss: 0.6087 - val_accuracy: 0.7006
# Epoch 24/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4348 - accuracy: 0.8018 - val_loss: 0.3820 - val_accuracy: 0.8242
# Epoch 25/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.4048 - accuracy: 0.8281 - val_loss: 0.3954 - val_accuracy: 0.8352
# Epoch 26/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4010 - accuracy: 0.8310 - val_loss: 0.3971 - val_accuracy: 0.8342
# Epoch 27/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.3934 - accuracy: 0.8333 - val_loss: 0.4093 - val_accuracy: 0.8222
# Epoch 28/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4048 - accuracy: 0.8318 - val_loss: 0.3622 - val_accuracy: 0.8453
# Epoch 29/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4027 - accuracy: 0.8272 - val_loss: 0.3948 - val_accuracy: 0.8289
# Epoch 30/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4000 - accuracy: 0.8315 - val_loss: 0.3927 - val_accuracy: 0.8186
# Epoch 31/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.3971 - accuracy: 0.8325 - val_loss: 0.4001 - val_accuracy: 0.8294
# Epoch 32/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.4247 - accuracy: 0.8049 - val_loss: 0.3910 - val_accuracy: 0.8325
# Epoch 33/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4457 - accuracy: 0.7785 - val_loss: 0.3987 - val_accuracy: 0.8191
# Epoch 34/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3961 - accuracy: 0.8233 - val_loss: 0.4039 - val_accuracy: 0.8225
# Epoch 35/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4021 - accuracy: 0.8329 - val_loss: 0.3975 - val_accuracy: 0.8396
# Epoch 36/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4082 - accuracy: 0.8314 - val_loss: 0.3886 - val_accuracy: 0.8107
# Epoch 37/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3995 - accuracy: 0.8299 - val_loss: 0.3977 - val_accuracy: 0.8293
# Epoch 38/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4096 - accuracy: 0.8267 - val_loss: 0.3896 - val_accuracy: 0.8389
# Epoch 39/50
# 926/926 [==============================] - 5s 6ms/step - loss: 0.4004 - accuracy: 0.8301 - val_loss: 0.4105 - val_accuracy: 0.8198
# Epoch 40/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3946 - accuracy: 0.8321 - val_loss: 0.4046 - val_accuracy: 0.8294
# Epoch 41/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4016 - accuracy: 0.8343 - val_loss: 0.3998 - val_accuracy: 0.8362
# Epoch 42/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4145 - accuracy: 0.8263 - val_loss: 0.3914 - val_accuracy: 0.8322
# Epoch 43/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4056 - accuracy: 0.8227 - val_loss: 0.4031 - val_accuracy: 0.8347
# Epoch 44/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4014 - accuracy: 0.8242 - val_loss: 0.3818 - val_accuracy: 0.8200
# Epoch 45/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3965 - accuracy: 0.8326 - val_loss: 0.4004 - val_accuracy: 0.8330
# Epoch 46/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3903 - accuracy: 0.8347 - val_loss: 0.4106 - val_accuracy: 0.8308
# Epoch 47/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.3979 - accuracy: 0.8332 - val_loss: 0.3601 - val_accuracy: 0.8440
# Epoch 48/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4014 - accuracy: 0.8294 - val_loss: 0.4122 - val_accuracy: 0.8227
# Epoch 49/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.3995 - accuracy: 0.8342 - val_loss: 0.3987 - val_accuracy: 0.8391
# Epoch 50/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4063 - accuracy: 0.8291 - val_loss: 0.4157 - val_accuracy: 0.8009

# %%
fig,ax= plt.subplots(1,2 , figsize=(30,10))

plt.subplot(1,2,1)
plt.title('Training and validation Accuracy', fontsize=12)
plt.plot(history.history['accuracy'], label='Training Acc')
plt.plot(history.history['val_accuracy'], label='Validation Acc')
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid(linestyle='--')

plt.subplot(1,2,2)
plt.title('Training and validation Loss', fontsize=12)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.ylabel('loss', fontsize=12)
plt.legend()
plt.grid(linestyle='--')
plt.show()

# %%
# Set random seed
tf.random.set_seed(42)

# 1. Create the model 
model_2 = tf.keras.Sequential([
  tf.keras.layers.Dense(100), # add 100 dense neurons
  tf.keras.layers.Dense(10), # add another layer with 10 neurons
  tf.keras.layers.Dense(1)
])

# 2. Compile the model
model_2.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Adamax(learning_rate= 0.01), # use AdaMax
                metrics=['accuracy'])

# 3. Fit the model
history = model_2.fit (X_train, y_train_full, epochs=50, verbose=1, batch_size=32, validation_data=(X_val,y_val)) # fit for 50 passes of the data
# Out:
# Epoch 1/50
# 926/926 [==============================] - 8s 5ms/step - loss: 2.1278 - accuracy: 0.8287 - val_loss: 1.6937 - val_accuracy: 0.8526
# Epoch 2/50
# 926/926 [==============================] - 4s 5ms/step - loss: 1.8604 - accuracy: 0.8476 - val_loss: 1.6164 - val_accuracy: 0.8516
# Epoch 3/50
# 926/926 [==============================] - 3s 3ms/step - loss: 1.4164 - accuracy: 0.8510 - val_loss: 1.2341 - val_accuracy: 0.8592
# Epoch 4/50
# 926/926 [==============================] - 3s 3ms/step - loss: 1.3463 - accuracy: 0.8541 - val_loss: 1.2347 - val_accuracy: 0.8604
# Epoch 5/50
# 926/926 [==============================] - 3s 3ms/step - loss: 1.3533 - accuracy: 0.8529 - val_loss: 1.6013 - val_accuracy: 0.8504
# Epoch 6/50
# 926/926 [==============================] - 4s 5ms/step - loss: 1.3621 - accuracy: 0.8506 - val_loss: 1.2257 - val_accuracy: 0.8617
# Epoch 7/50
# 926/926 [==============================] - 3s 3ms/step - loss: 1.3333 - accuracy: 0.8472 - val_loss: 1.2020 - val_accuracy: 0.8597
# Epoch 8/50
# 926/926 [==============================] - 3s 3ms/step - loss: 1.3246 - accuracy: 0.8492 - val_loss: 1.2248 - val_accuracy: 0.8614
# Epoch 9/50
# 926/926 [==============================] - 4s 4ms/step - loss: 1.1798 - accuracy: 0.8306 - val_loss: 0.6285 - val_accuracy: 0.8144
# Epoch 10/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4804 - accuracy: 0.8172 - val_loss: 0.3965 - val_accuracy: 0.8286
# Epoch 11/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4059 - accuracy: 0.8268 - val_loss: 0.3755 - val_accuracy: 0.8414
# Epoch 12/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3995 - accuracy: 0.8321 - val_loss: 0.4001 - val_accuracy: 0.8337
# Epoch 13/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4052 - accuracy: 0.8326 - val_loss: 0.3979 - val_accuracy: 0.8354
# Epoch 14/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4046 - accuracy: 0.8305 - val_loss: 0.4007 - val_accuracy: 0.8369
# Epoch 15/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4140 - accuracy: 0.8273 - val_loss: 0.4339 - val_accuracy: 0.8114
# Epoch 16/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4037 - accuracy: 0.8190 - val_loss: 0.3830 - val_accuracy: 0.8291
# Epoch 17/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4046 - accuracy: 0.8317 - val_loss: 0.3991 - val_accuracy: 0.8257
# Epoch 18/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4018 - accuracy: 0.8296 - val_loss: 0.4139 - val_accuracy: 0.8313
# Epoch 19/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4029 - accuracy: 0.8285 - val_loss: 0.3814 - val_accuracy: 0.8318
# Epoch 20/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.4194 - accuracy: 0.8179 - val_loss: 0.3996 - val_accuracy: 0.8294
# Epoch 21/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4040 - accuracy: 0.8314 - val_loss: 0.3963 - val_accuracy: 0.8232
# Epoch 22/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.3978 - accuracy: 0.8261 - val_loss: 0.4047 - val_accuracy: 0.8310
# Epoch 23/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4081 - accuracy: 0.8275 - val_loss: 0.3932 - val_accuracy: 0.8195
# Epoch 24/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4094 - accuracy: 0.8215 - val_loss: 0.3924 - val_accuracy: 0.8267
# Epoch 25/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3976 - accuracy: 0.8316 - val_loss: 0.4044 - val_accuracy: 0.8271
# Epoch 26/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4028 - accuracy: 0.8323 - val_loss: 0.3996 - val_accuracy: 0.8352
# Epoch 27/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4049 - accuracy: 0.8324 - val_loss: 0.3709 - val_accuracy: 0.8327
# Epoch 28/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3994 - accuracy: 0.8292 - val_loss: 0.3972 - val_accuracy: 0.8414
# Epoch 29/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4192 - accuracy: 0.8217 - val_loss: 0.3982 - val_accuracy: 0.8305
# Epoch 30/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.3977 - accuracy: 0.8264 - val_loss: 0.3658 - val_accuracy: 0.8485
# Epoch 31/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.3979 - accuracy: 0.8332 - val_loss: 0.4160 - val_accuracy: 0.8094
# Epoch 32/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.3915 - accuracy: 0.8297 - val_loss: 0.3960 - val_accuracy: 0.8411
# Epoch 33/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4030 - accuracy: 0.8297 - val_loss: 0.3745 - val_accuracy: 0.8367
# Epoch 34/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4005 - accuracy: 0.8333 - val_loss: 0.3993 - val_accuracy: 0.8433
# Epoch 35/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.3952 - accuracy: 0.8328 - val_loss: 0.3956 - val_accuracy: 0.8392
# Epoch 36/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4041 - accuracy: 0.8232 - val_loss: 0.4024 - val_accuracy: 0.8235
# Epoch 37/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3905 - accuracy: 0.8332 - val_loss: 0.3984 - val_accuracy: 0.8092
# Epoch 38/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.3990 - accuracy: 0.8304 - val_loss: 0.3879 - val_accuracy: 0.8367
# Epoch 39/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.3903 - accuracy: 0.8339 - val_loss: 0.3945 - val_accuracy: 0.8095
# Epoch 40/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4009 - accuracy: 0.8312 - val_loss: 0.3974 - val_accuracy: 0.8359
# Epoch 41/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4042 - accuracy: 0.8316 - val_loss: 0.3996 - val_accuracy: 0.8350
# Epoch 42/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4033 - accuracy: 0.8316 - val_loss: 0.3945 - val_accuracy: 0.8377
# Epoch 43/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4007 - accuracy: 0.8304 - val_loss: 0.4007 - val_accuracy: 0.8403
# Epoch 44/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3977 - accuracy: 0.8332 - val_loss: 0.3963 - val_accuracy: 0.8308
# Epoch 45/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.3966 - accuracy: 0.8336 - val_loss: 0.4012 - val_accuracy: 0.8333
# Epoch 46/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4017 - accuracy: 0.8327 - val_loss: 0.3876 - val_accuracy: 0.8180
# Epoch 47/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4013 - accuracy: 0.8315 - val_loss: 0.4094 - val_accuracy: 0.8099
# Epoch 48/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3950 - accuracy: 0.8335 - val_loss: 0.4067 - val_accuracy: 0.8256
# Epoch 49/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3918 - accuracy: 0.8352 - val_loss: 0.3656 - val_accuracy: 0.8509
# Epoch 50/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.3841 - accuracy: 0.8379 - val_loss: 0.3945 - val_accuracy: 0.8502

# %%
fig,ax= plt.subplots(1,2 , figsize=(30,10))

plt.subplot(1,2,1)
plt.title('Training and validation Accuracy', fontsize=12)
plt.plot(history.history['accuracy'], label='Training Acc')
plt.plot(history.history['val_accuracy'], label='Validation Acc')
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid(linestyle='--')

plt.subplot(1,2,2)
plt.title('Training and validation Loss', fontsize=12)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.ylabel('loss', fontsize=12)
plt.legend()
plt.grid(linestyle='--')
plt.show()

# %%
# Set random seed
tf.random.set_seed(42)

# 1. Create the model 
model3 = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation='elu'), # add 100 dense neurons
  tf.keras.layers.Dense(50, activation='elu'),
  tf.keras.layers.Dense(10, activation='elu'), # add another layer with 10 neurons
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# 2. Compile the model
model3.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Nadam(learning_rate= 0.01), # use Nadam
                metrics=['accuracy'])

# 3. Fit the model
history = model3.fit(X_train, y_train_full, epochs=50, verbose=1, batch_size=32, validation_data=(X_val,y_val)) # fit for 100 passes of the data
# Out:
# Epoch 1/50
# 926/926 [==============================] - 7s 5ms/step - loss: 0.3295 - accuracy: 0.8508 - val_loss: 0.2940 - val_accuracy: 0.8622
# Epoch 2/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2809 - accuracy: 0.8525 - val_loss: 0.2762 - val_accuracy: 0.8556
# Epoch 3/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2624 - accuracy: 0.8520 - val_loss: 0.2546 - val_accuracy: 0.8597
# Epoch 4/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2578 - accuracy: 0.8557 - val_loss: 0.2519 - val_accuracy: 0.8490
# Epoch 5/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2563 - accuracy: 0.8575 - val_loss: 0.2450 - val_accuracy: 0.8740
# Epoch 6/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2493 - accuracy: 0.8690 - val_loss: 0.2246 - val_accuracy: 0.8764
# Epoch 7/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2291 - accuracy: 0.8783 - val_loss: 0.2197 - val_accuracy: 0.8761
# Epoch 8/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2334 - accuracy: 0.8844 - val_loss: 0.2096 - val_accuracy: 0.8793
# Epoch 9/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2260 - accuracy: 0.8827 - val_loss: 0.2114 - val_accuracy: 0.8808
# Epoch 10/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2207 - accuracy: 0.8820 - val_loss: 0.2279 - val_accuracy: 0.8877
# Epoch 11/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2209 - accuracy: 0.8837 - val_loss: 0.2112 - val_accuracy: 0.8968
# Epoch 12/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2165 - accuracy: 0.8851 - val_loss: 0.2019 - val_accuracy: 0.8994
# Epoch 13/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2149 - accuracy: 0.8856 - val_loss: 0.2050 - val_accuracy: 0.8810
# Epoch 14/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2375 - accuracy: 0.8856 - val_loss: 0.2089 - val_accuracy: 0.8989
# Epoch 15/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2141 - accuracy: 0.8857 - val_loss: 0.2045 - val_accuracy: 0.8833
# Epoch 16/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2154 - accuracy: 0.8871 - val_loss: 0.1997 - val_accuracy: 0.8990
# Epoch 17/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2127 - accuracy: 0.8887 - val_loss: 0.2058 - val_accuracy: 0.8815
# Epoch 18/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2316 - accuracy: 0.8829 - val_loss: 0.2364 - val_accuracy: 0.8994
# Epoch 19/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2510 - accuracy: 0.8890 - val_loss: 0.2367 - val_accuracy: 0.9019
# Epoch 20/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2472 - accuracy: 0.8882 - val_loss: 0.2353 - val_accuracy: 0.8992
# Epoch 21/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2507 - accuracy: 0.8884 - val_loss: 0.2415 - val_accuracy: 0.8977
# Epoch 22/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2504 - accuracy: 0.8896 - val_loss: 0.2334 - val_accuracy: 0.9002
# Epoch 23/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2403 - accuracy: 0.8888 - val_loss: 0.2056 - val_accuracy: 0.8983
# Epoch 24/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2114 - accuracy: 0.8872 - val_loss: 0.1927 - val_accuracy: 0.9017
# Epoch 25/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2101 - accuracy: 0.8890 - val_loss: 0.1949 - val_accuracy: 0.8874
# Epoch 26/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2127 - accuracy: 0.8866 - val_loss: 0.1951 - val_accuracy: 0.9021
# Epoch 27/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2109 - accuracy: 0.8875 - val_loss: 0.2177 - val_accuracy: 0.8771
# Epoch 28/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2093 - accuracy: 0.8879 - val_loss: 0.1910 - val_accuracy: 0.9031
# Epoch 29/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2126 - accuracy: 0.8895 - val_loss: 0.1967 - val_accuracy: 0.9044
# Epoch 30/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2212 - accuracy: 0.8856 - val_loss: 0.1969 - val_accuracy: 0.8860
# Epoch 31/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2078 - accuracy: 0.8895 - val_loss: 0.2044 - val_accuracy: 0.8823
# Epoch 32/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2089 - accuracy: 0.8876 - val_loss: 0.1929 - val_accuracy: 0.9012
# Epoch 33/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2076 - accuracy: 0.8876 - val_loss: 0.1981 - val_accuracy: 0.9005
# Epoch 34/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2051 - accuracy: 0.8898 - val_loss: 0.1985 - val_accuracy: 0.8850
# Epoch 35/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2215 - accuracy: 0.8889 - val_loss: 0.1983 - val_accuracy: 0.9007
# Epoch 36/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2169 - accuracy: 0.8907 - val_loss: 0.1891 - val_accuracy: 0.8882
# Epoch 37/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2029 - accuracy: 0.8922 - val_loss: 0.2003 - val_accuracy: 0.8837
# Epoch 38/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2095 - accuracy: 0.8898 - val_loss: 0.2021 - val_accuracy: 0.9021
# Epoch 39/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1866 - accuracy: 0.9169 - val_loss: 0.1823 - val_accuracy: 0.9137
# Epoch 40/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1755 - accuracy: 0.9288 - val_loss: 0.1673 - val_accuracy: 0.9252
# Epoch 41/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1738 - accuracy: 0.9291 - val_loss: 0.1746 - val_accuracy: 0.9216
# Epoch 42/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1734 - accuracy: 0.9289 - val_loss: 0.1676 - val_accuracy: 0.9240
# Epoch 43/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1735 - accuracy: 0.9287 - val_loss: 0.1653 - val_accuracy: 0.9254
# Epoch 44/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1738 - accuracy: 0.9278 - val_loss: 0.1665 - val_accuracy: 0.9269
# Epoch 45/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1728 - accuracy: 0.9299 - val_loss: 0.1663 - val_accuracy: 0.9235
# Epoch 46/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1967 - accuracy: 0.9250 - val_loss: 0.1704 - val_accuracy: 0.9206
# Epoch 47/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1685 - accuracy: 0.9309 - val_loss: 0.1636 - val_accuracy: 0.9260
# Epoch 48/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1685 - accuracy: 0.9305 - val_loss: 0.1617 - val_accuracy: 0.9279
# Epoch 49/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1677 - accuracy: 0.9303 - val_loss: 0.1621 - val_accuracy: 0.9265
# Epoch 50/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1686 - accuracy: 0.9315 - val_loss: 0.1689 - val_accuracy: 0.9254

# %% [markdown]
# # Model Evaluatiuon

# %%
fig,ax= plt.subplots(1,2 , figsize=(30,10))

plt.subplot(1,2,1)
plt.title('Training and validation Accuracy', fontsize=12)
plt.plot(history.history['accuracy'], label='Training Acc')
plt.plot(history.history['val_accuracy'], label='Validation Acc')
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid(linestyle='--')

plt.subplot(1,2,2)
plt.title('Training and validation Loss', fontsize=12)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.ylabel('loss', fontsize=12)
plt.legend()
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# # Model Functional API

# %%
# functional API
input_layer= tf.keras.Input(shape=(X_train.shape[1:]),name='input_layer')

hidden_1= Dense(30, activation='relu', name='hidden_1')(input_layer)
hidden_2= Dense(30, activation='relu', name='hidden_2')(hidden_1)
hidden_3= Dense(10, activation='relu', name='hidden_3')(hidden_2)
concat= tf.keras.layers.concatenate([input_layer,hidden_3])

output_layer= Dense(1, activation='sigmoid', name='output_layer')(concat)

model_func= Model(inputs=input_layer,
                  outputs=output_layer)

model_func.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
tf.keras.utils.plot_model(model_func, show_shapes=True)

# %%
callbacks2= [
    EarlyStopping(monitor='val_loss', patience= 3, restore_best_weights=True),
    ModelCheckpoint('model_best_func.hdf5', monitor='val_loss', save_best_only=True)
]

# %%
# Set random seed
tf.random.set_seed(42)

# 1. Create the model 
model4 = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation='relu'), # add 100 dense neurons
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(10, activation='relu'), # add another layer with 10 neurons
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# 2. Compile the model
model4.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Nadam(learning_rate= 0.01), # use Nadam
                metrics=['accuracy'])

# 3. Fit the model
history = model4.fit(X_train, y_train_full, epochs=50, verbose=1, batch_size=32, validation_data=(X_val,y_val)) # fit for 50 passes of the data
# Out:
# Epoch 1/50
# 926/926 [==============================] - 6s 4ms/step - loss: 0.3322 - accuracy: 0.8503 - val_loss: 0.2771 - val_accuracy: 0.8646
# Epoch 2/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2713 - accuracy: 0.8525 - val_loss: 0.2572 - val_accuracy: 0.8495
# Epoch 3/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2598 - accuracy: 0.8558 - val_loss: 0.2518 - val_accuracy: 0.8494
# Epoch 4/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2539 - accuracy: 0.8683 - val_loss: 0.2393 - val_accuracy: 0.8853
# Epoch 5/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2335 - accuracy: 0.8980 - val_loss: 0.2156 - val_accuracy: 0.9108
# Epoch 6/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2162 - accuracy: 0.9102 - val_loss: 0.2333 - val_accuracy: 0.8995
# Epoch 7/50
# 926/926 [==============================] - 5s 6ms/step - loss: 0.1957 - accuracy: 0.9214 - val_loss: 0.1937 - val_accuracy: 0.9157
# Epoch 8/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1873 - accuracy: 0.9244 - val_loss: 0.2084 - val_accuracy: 0.9097
# Epoch 9/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1855 - accuracy: 0.9239 - val_loss: 0.1795 - val_accuracy: 0.9249
# Epoch 10/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1840 - accuracy: 0.9252 - val_loss: 0.1844 - val_accuracy: 0.9198
# Epoch 11/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1787 - accuracy: 0.9246 - val_loss: 0.1748 - val_accuracy: 0.9286
# Epoch 12/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1732 - accuracy: 0.9262 - val_loss: 0.1765 - val_accuracy: 0.9176
# Epoch 13/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1719 - accuracy: 0.9278 - val_loss: 0.1690 - val_accuracy: 0.9276
# Epoch 14/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1683 - accuracy: 0.9264 - val_loss: 0.1616 - val_accuracy: 0.9314
# Epoch 15/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1677 - accuracy: 0.9274 - val_loss: 0.1584 - val_accuracy: 0.9352
# Epoch 16/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1662 - accuracy: 0.9283 - val_loss: 0.1582 - val_accuracy: 0.9227
# Epoch 17/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1643 - accuracy: 0.9285 - val_loss: 0.1652 - val_accuracy: 0.9262
# Epoch 18/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1663 - accuracy: 0.9299 - val_loss: 0.1542 - val_accuracy: 0.9292
# Epoch 19/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1669 - accuracy: 0.9279 - val_loss: 0.1627 - val_accuracy: 0.9216
# Epoch 20/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1632 - accuracy: 0.9293 - val_loss: 0.1604 - val_accuracy: 0.9318
# Epoch 21/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1618 - accuracy: 0.9303 - val_loss: 0.1545 - val_accuracy: 0.9311
# Epoch 22/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1614 - accuracy: 0.9295 - val_loss: 0.1592 - val_accuracy: 0.9254
# Epoch 23/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1618 - accuracy: 0.9302 - val_loss: 0.1525 - val_accuracy: 0.9343
# Epoch 24/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1601 - accuracy: 0.9300 - val_loss: 0.1578 - val_accuracy: 0.9279
# Epoch 25/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1583 - accuracy: 0.9313 - val_loss: 0.1602 - val_accuracy: 0.9216
# Epoch 26/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1600 - accuracy: 0.9305 - val_loss: 0.1482 - val_accuracy: 0.9325
# Epoch 27/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1587 - accuracy: 0.9304 - val_loss: 0.1632 - val_accuracy: 0.9189
# Epoch 28/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1571 - accuracy: 0.9315 - val_loss: 0.1617 - val_accuracy: 0.9216
# Epoch 29/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1564 - accuracy: 0.9325 - val_loss: 0.1514 - val_accuracy: 0.9355
# Epoch 30/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1547 - accuracy: 0.9330 - val_loss: 0.1487 - val_accuracy: 0.9330
# Epoch 31/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1566 - accuracy: 0.9325 - val_loss: 0.1595 - val_accuracy: 0.9298
# Epoch 32/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1532 - accuracy: 0.9332 - val_loss: 0.1632 - val_accuracy: 0.9352
# Epoch 33/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1582 - accuracy: 0.9322 - val_loss: 0.1693 - val_accuracy: 0.9203
# Epoch 34/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1546 - accuracy: 0.9328 - val_loss: 0.1498 - val_accuracy: 0.9308
# Epoch 35/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1545 - accuracy: 0.9338 - val_loss: 0.1500 - val_accuracy: 0.9357
# Epoch 36/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1537 - accuracy: 0.9343 - val_loss: 0.1461 - val_accuracy: 0.9331
# Epoch 37/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1511 - accuracy: 0.9353 - val_loss: 0.1477 - val_accuracy: 0.9392
# Epoch 38/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1512 - accuracy: 0.9365 - val_loss: 0.1434 - val_accuracy: 0.9370
# Epoch 39/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1526 - accuracy: 0.9344 - val_loss: 0.1519 - val_accuracy: 0.9331
# Epoch 40/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1524 - accuracy: 0.9337 - val_loss: 0.1495 - val_accuracy: 0.9345
# Epoch 41/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1515 - accuracy: 0.9361 - val_loss: 0.1455 - val_accuracy: 0.9401
# Epoch 42/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1484 - accuracy: 0.9358 - val_loss: 0.1401 - val_accuracy: 0.9417
# Epoch 43/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1480 - accuracy: 0.9365 - val_loss: 0.1476 - val_accuracy: 0.9304
# Epoch 44/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1473 - accuracy: 0.9367 - val_loss: 0.1443 - val_accuracy: 0.9362
# Epoch 45/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1488 - accuracy: 0.9366 - val_loss: 0.1520 - val_accuracy: 0.9316
# Epoch 46/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1465 - accuracy: 0.9384 - val_loss: 0.1655 - val_accuracy: 0.9316
# Epoch 47/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1493 - accuracy: 0.9358 - val_loss: 0.1432 - val_accuracy: 0.9368
# Epoch 48/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1500 - accuracy: 0.9361 - val_loss: 0.1398 - val_accuracy: 0.9399
# Epoch 49/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1451 - accuracy: 0.9379 - val_loss: 0.1498 - val_accuracy: 0.9390
# Epoch 50/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1465 - accuracy: 0.9359 - val_loss: 0.1413 - val_accuracy: 0.9360

# %%
fig,ax= plt.subplots(1,2 , figsize=(30,10))

plt.subplot(1,2,1)
plt.title('Training and validation Accuracy', fontsize=12)
plt.plot(history.history['accuracy'], label='Training Acc')
plt.plot(history.history['val_accuracy'], label='Validation Acc')
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid(linestyle='--')

plt.subplot(1,2,2)
plt.title('Training and validation Loss', fontsize=12)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.ylabel('loss', fontsize=12)
plt.legend()
plt.grid(linestyle='--')
plt.show()

# %%
# Set random seed
tf.random.set_seed(42)

# 1. Create the model 
model5 = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation='relu'), # add 100 dense neurons
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(10, activation='relu'), # add another layer with 10 neurons
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# 2. Compile the model
model5.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Adam(learning_rate= 0.01), # use Nadam
                metrics=['accuracy'])

# 3. Fit the model
history = model5.fit(X_train, y_train_full, epochs=50, verbose=1, batch_size=32, validation_data=(X_val,y_val)) # fit for 50 passes of the data
# Out:
# Epoch 1/50
# 926/926 [==============================] - 6s 5ms/step - loss: 0.3360 - accuracy: 0.8512 - val_loss: 0.3025 - val_accuracy: 0.8615
# Epoch 2/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2960 - accuracy: 0.8533 - val_loss: 0.2762 - val_accuracy: 0.8445
# Epoch 3/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2629 - accuracy: 0.8571 - val_loss: 0.2494 - val_accuracy: 0.8649
# Epoch 4/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2621 - accuracy: 0.8590 - val_loss: 0.2438 - val_accuracy: 0.8764
# Epoch 5/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2549 - accuracy: 0.8776 - val_loss: 0.2390 - val_accuracy: 0.8735
# Epoch 6/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2303 - accuracy: 0.9035 - val_loss: 0.2411 - val_accuracy: 0.8725
# Epoch 7/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2040 - accuracy: 0.9167 - val_loss: 0.1998 - val_accuracy: 0.9137
# Epoch 8/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1891 - accuracy: 0.9181 - val_loss: 0.1784 - val_accuracy: 0.9189
# Epoch 9/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1817 - accuracy: 0.9187 - val_loss: 0.1695 - val_accuracy: 0.9193
# Epoch 10/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1761 - accuracy: 0.9210 - val_loss: 0.1803 - val_accuracy: 0.9164
# Epoch 11/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1815 - accuracy: 0.9206 - val_loss: 0.1658 - val_accuracy: 0.9286
# Epoch 12/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1718 - accuracy: 0.9234 - val_loss: 0.1813 - val_accuracy: 0.9168
# Epoch 13/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1734 - accuracy: 0.9242 - val_loss: 0.1731 - val_accuracy: 0.9189
# Epoch 14/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1695 - accuracy: 0.9232 - val_loss: 0.1725 - val_accuracy: 0.9267
# Epoch 15/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1693 - accuracy: 0.9245 - val_loss: 0.1670 - val_accuracy: 0.9230
# Epoch 16/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.1665 - accuracy: 0.9232 - val_loss: 0.1588 - val_accuracy: 0.9225
# Epoch 17/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1684 - accuracy: 0.9245 - val_loss: 0.1612 - val_accuracy: 0.9237
# Epoch 18/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.1686 - accuracy: 0.9233 - val_loss: 0.1541 - val_accuracy: 0.9282
# Epoch 19/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1632 - accuracy: 0.9259 - val_loss: 0.1744 - val_accuracy: 0.9127
# Epoch 20/50
# 926/926 [==============================] - 5s 6ms/step - loss: 0.1636 - accuracy: 0.9249 - val_loss: 0.1608 - val_accuracy: 0.9287
# Epoch 21/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1659 - accuracy: 0.9260 - val_loss: 0.1719 - val_accuracy: 0.9306
# Epoch 22/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1644 - accuracy: 0.9267 - val_loss: 0.1545 - val_accuracy: 0.9257
# Epoch 23/50
# 926/926 [==============================] - 6s 6ms/step - loss: 0.1596 - accuracy: 0.9274 - val_loss: 0.1533 - val_accuracy: 0.9245
# Epoch 24/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1600 - accuracy: 0.9259 - val_loss: 0.1659 - val_accuracy: 0.9262
# Epoch 25/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.1595 - accuracy: 0.9272 - val_loss: 0.1487 - val_accuracy: 0.9220
# Epoch 26/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1593 - accuracy: 0.9245 - val_loss: 0.1464 - val_accuracy: 0.9240
# Epoch 27/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1565 - accuracy: 0.9272 - val_loss: 0.1644 - val_accuracy: 0.9195
# Epoch 28/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1578 - accuracy: 0.9264 - val_loss: 0.1753 - val_accuracy: 0.9292
# Epoch 29/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1564 - accuracy: 0.9274 - val_loss: 0.1468 - val_accuracy: 0.9348
# Epoch 30/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1564 - accuracy: 0.9269 - val_loss: 0.1459 - val_accuracy: 0.9247
# Epoch 31/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1559 - accuracy: 0.9270 - val_loss: 0.1476 - val_accuracy: 0.9309
# Epoch 32/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1549 - accuracy: 0.9276 - val_loss: 0.1576 - val_accuracy: 0.9289
# Epoch 33/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1528 - accuracy: 0.9272 - val_loss: 0.1818 - val_accuracy: 0.9186
# Epoch 34/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.1543 - accuracy: 0.9277 - val_loss: 0.1509 - val_accuracy: 0.9213
# Epoch 35/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1525 - accuracy: 0.9288 - val_loss: 0.1433 - val_accuracy: 0.9282
# Epoch 36/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1521 - accuracy: 0.9287 - val_loss: 0.1519 - val_accuracy: 0.9205
# Epoch 37/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.1526 - accuracy: 0.9266 - val_loss: 0.1565 - val_accuracy: 0.9238
# Epoch 38/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1558 - accuracy: 0.9287 - val_loss: 0.1459 - val_accuracy: 0.9222
# Epoch 39/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1500 - accuracy: 0.9276 - val_loss: 0.1455 - val_accuracy: 0.9321
# Epoch 40/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1513 - accuracy: 0.9261 - val_loss: 0.1414 - val_accuracy: 0.9343
# Epoch 41/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.1505 - accuracy: 0.9270 - val_loss: 0.1470 - val_accuracy: 0.9220
# Epoch 42/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1506 - accuracy: 0.9269 - val_loss: 0.1419 - val_accuracy: 0.9335
# Epoch 43/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1491 - accuracy: 0.9281 - val_loss: 0.1414 - val_accuracy: 0.9227
# Epoch 44/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1449 - accuracy: 0.9288 - val_loss: 0.1382 - val_accuracy: 0.9260
# Epoch 45/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1504 - accuracy: 0.9278 - val_loss: 0.1619 - val_accuracy: 0.9108
# Epoch 46/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1446 - accuracy: 0.9297 - val_loss: 0.1463 - val_accuracy: 0.9325
# Epoch 47/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.1448 - accuracy: 0.9307 - val_loss: 0.1481 - val_accuracy: 0.9341
# Epoch 48/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1442 - accuracy: 0.9287 - val_loss: 0.1338 - val_accuracy: 0.9372
# Epoch 49/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1438 - accuracy: 0.9290 - val_loss: 0.1436 - val_accuracy: 0.9365
# Epoch 50/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1452 - accuracy: 0.9296 - val_loss: 0.1426 - val_accuracy: 0.9358

# %%
fig,ax= plt.subplots(1,2 , figsize=(30,10))

plt.subplot(1,2,1)
plt.title('Training and validation Accuracy', fontsize=12)
plt.plot(history.history['accuracy'], label='Training Acc')
plt.plot(history.history['val_accuracy'], label='Validation Acc')
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid(linestyle='--')

plt.subplot(1,2,2)
plt.title('Training and validation Loss', fontsize=12)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.ylabel('loss', fontsize=12)
plt.legend()
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# # Model Saving

# %%
pickle.dump(full_pipeline, open('.pkl', 'wb'))

# save model
model4.save('best_model.h5')
