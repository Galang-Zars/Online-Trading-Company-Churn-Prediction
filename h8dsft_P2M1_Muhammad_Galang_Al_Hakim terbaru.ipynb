# %% [markdown]
# # Phase 2 Milestone 1

# %% [markdown]
# ### Muhammad Galang Al-Hakim

# %% [markdown]
# ### HCK-004

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

#untuk model
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model, load_model
# from tensorflow.python.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Input, Dense, Dropout

from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
# %matplotlib inline
import tensorflow as tf
# !pip install feature-engine
from feature_engine.outliers import Winsorizer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras import regularizers
#preprocessing
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.compose import ColumnTransformer

#evaluasi
from sklearn.metrics import confusion_matrix ,accuracy_score, roc_curve,roc_auc_score,precision_score, recall_score, classification_report, f1_score

import joblib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: feature-engine in /usr/local/lib/python3.9/dist-packages (1.6.0)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.9/dist-packages (from feature-engine) (1.22.4)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.9/dist-packages (from feature-engine) (1.4.4)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from feature-engine) (0.13.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from feature-engine) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from feature-engine) (1.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.3->feature-engine) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.3->feature-engine) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0.0->feature-engine) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0.0->feature-engine) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.11.1->feature-engine) (23.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.11.1->feature-engine) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels>=0.11.1->feature-engine) (1.16.0)

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv('/content/churn.txt')
df
# Out:
#                 user_id  age gender region_category membership_category  \
# 0      9f420209e7d129f3   29      F             NaN       No Membership
# 1      ac6e97806267549e   50      M             NaN    Basic Membership
# 2      a6aa19b1580eed4e   26      F            City   Silver Membership
# 3      aeee343277211c2f   63      F         Village       No Membership
# 4      82448b5c8ce6390c   64      M            Town   Silver Membership
# ...                 ...  ...    ...             ...                 ...
# 37005  924e9c06f0c73817   36      M            Town     Gold Membership
# 37006  90e22286ac0acf04   27      F            City     Gold Membership
# 37007  9329a6297407334a   20      M             NaN     Gold Membership
# 37008  a4403ddda8fcf9f3   38      F            City     Gold Membership
# 37009  93b5d0330d24fa15   36      M            Town     Gold Membership
#
#       joining_date joined_through_referral     preferred_offer_types  \
# 0       2017-04-05                     Yes            Without Offers
# 1       2017-03-31                     Yes            Without Offers
# 2       2017-02-11                     NaN  Credit/Debit Card Offers
# 3       2015-12-23                      No  Credit/Debit Card Offers
# 4       2015-03-20                     NaN     Gift Vouchers/Coupons
# ...            ...                     ...                       ...
# 37005   2015-03-05                     NaN  Credit/Debit Card Offers
# 37006   2017-01-15                     Yes            Without Offers
# 37007   2015-07-11                     Yes            Without Offers
# 37008   2016-05-25                     Yes            Without Offers
# 37009   2016-10-18                     NaN            Without Offers
#
#       medium_of_operation internet_option  ... avg_time_spent  \
# 0                     NaN           Wi-Fi  ...    1184.490000
# 1                 Desktop     Fiber_Optic  ...     338.150000
# 2                     NaN     Fiber_Optic  ...     235.140000
# 3                 Desktop     Fiber_Optic  ...      56.670000
# 4              Smartphone           Wi-Fi  ...     153.990000
# ...                   ...             ...  ...            ...
# 37005                 NaN     Fiber_Optic  ...     199.330000
# 37006             Desktop           Wi-Fi  ...     368.500000
# 37007                 NaN     Mobile_Data  ...     272.130000
# 37008             Desktop           Wi-Fi  ...      65.070000
# 37009                Both     Fiber_Optic  ...     972.776679
#
#        avg_transaction_value  avg_frequency_login_days  points_in_wallet  \
# 0                   38604.69                      10.0            627.48
# 1                    7665.66                      17.0            575.97
# 2                   37671.69                       5.0            767.93
# 3                   15678.14                      11.0            590.22
# 4                    8422.68                       0.0            722.04
# ...                      ...                       ...               ...
# 37005               29455.29                       9.0            846.52
# 37006               27038.47                       8.0            835.98
# 37007               39305.35                      27.0            714.90
# 37008               46108.73                       6.0            744.99
# 37009               26905.49                      22.0            700.93
#
#        used_special_discount  offer_application_preference past_complaint  \
# 0                        Yes                           Yes            Yes
# 1                        Yes                            No            Yes
# 2                        Yes                            No            Yes
# 3                         No                           Yes             No
# 4                        Yes                            No             No
# ...                      ...                           ...            ...
# 37005                    Yes                           Yes             No
# 37006                     No                           Yes             No
# 37007                    Yes                           Yes            Yes
# 37008                     No                           Yes             No
# 37009                    Yes                            No            Yes
#
#                complaint_status               feedback churn_risk_score
# 0      No Information Available           Poor Website                1
# 1      No Information Available  Poor Customer Service                1
# 2      No Information Available           Too many ads                0
# 3                Not Applicable           Too many ads                1
# 4                Not Applicable   Poor Product Quality                0
# ...                         ...                    ...              ...
# 37005            Not Applicable  User Friendly Website                0
# 37006            Not Applicable       Reasonable Price                0
# 37007                    Solved  Poor Customer Service                0
# 37008            Not Applicable           Poor Website                0
# 37009  No Information Available  Poor Customer Service                1
#
# [37010 rows x 22 columns]

# %% [markdown]
# ### Dataset Description

# %% [markdown]
# - **user_id** = ID of a customer
# - **age** = Age of a customer
# - **gender** = Gender of a customer
# - **region_category** = Region that a customer belongs to
# - **membership_category** = Category of the membership that a customer is using
# - **joining_date** = Date when a customer became a member
# - **joined_through referral**	= Whether a customer joined using any referral code or ID
# - **preferred_offer types** = Type of offer that a customer prefers
# - **medium_of operation** = Medium of operation that a customer uses for transactions
# - **internet_option** = Type of internet service a customer uses
# - **last_visit_time** = The last time a customer visited the website
# - **days_since_last_login** = Number of days since a customer last logged into the website
# - **avg_time_spent** = Average time spent by a customer on the website
# - **avg_transaction_value** = Average transaction value of a customer
# - **avg_frequency_login_days** = Number of times a customer has logged in to the website
# - **points_in_wallet** = Points awarded to a customer on each transaction
# - **used_special_discount** = Whether a customer uses special discounts offered
# - **offer_application_preference**	=  Whether a customer prefers offers
# - **past_complaint** = Whether a customer has raised any complaints
# - **complaint_status** = Whether the complaints raised by a customer was resolved
# - **feedback** = Feedback provided by a customer
# - **churn_risk_score** = Churn score 0 : Not churn, 1 : Churn

# %%
df.head(10)
# Out:
#             user_id  age gender region_category  membership_category  \
# 0  9f420209e7d129f3   29      F             NaN        No Membership
# 1  ac6e97806267549e   50      M             NaN     Basic Membership
# 2  a6aa19b1580eed4e   26      F            City    Silver Membership
# 3  aeee343277211c2f   63      F         Village        No Membership
# 4  82448b5c8ce6390c   64      M            Town    Silver Membership
# 5  96fbb6f63244b1f4   35      M            Town   Premium Membership
# 6  a52bc51378ecb057   43      M             NaN      Gold Membership
# 7  94f338d20bf0f2b2   15      M            City        No Membership
# 8  85c7996b17862e57   49      M            Town  Platinum Membership
# 9  8a1625846d7a198b   35      F            Town     Basic Membership
#
#   joining_date joined_through_referral     preferred_offer_types  \
# 0   2017-04-05                     Yes            Without Offers
# 1   2017-03-31                     Yes            Without Offers
# 2   2017-02-11                     NaN  Credit/Debit Card Offers
# 3   2015-12-23                      No  Credit/Debit Card Offers
# 4   2015-03-20                     NaN     Gift Vouchers/Coupons
# 5   2016-08-16                      No  Credit/Debit Card Offers
# 6   2017-03-09                     Yes     Gift Vouchers/Coupons
# 7   2016-09-11                      No  Credit/Debit Card Offers
# 8   2017-04-24                     Yes            Without Offers
# 9   2016-12-01                     Yes  Credit/Debit Card Offers
#
#   medium_of_operation internet_option  ... avg_time_spent  \
# 0                 NaN           Wi-Fi  ...    1184.490000
# 1             Desktop     Fiber_Optic  ...     338.150000
# 2                 NaN     Fiber_Optic  ...     235.140000
# 3             Desktop     Fiber_Optic  ...      56.670000
# 4          Smartphone           Wi-Fi  ...     153.990000
# 5                 NaN           Wi-Fi  ...    1397.318999
# 6          Smartphone     Mobile_Data  ...     416.300000
# 7          Smartphone           Wi-Fi  ...      34.070000
# 8                 NaN     Fiber_Optic  ...     650.120000
# 9             Desktop     Mobile_Data  ...     106.230000
#
#    avg_transaction_value  avg_frequency_login_days  points_in_wallet  \
# 0               38604.69                      10.0         627.48000
# 1                7665.66                      17.0         575.97000
# 2               37671.69                       5.0         767.93000
# 3               15678.14                      11.0         590.22000
# 4                8422.68                       0.0         722.04000
# 5               29664.01                      28.0         782.49000
# 6               13160.39                      24.0         712.94000
# 7                9151.14                      29.0         655.43000
# 8               81628.48                      11.0           0.00000
# 9               28232.59                      16.0         984.93392
#
#    used_special_discount  offer_application_preference past_complaint  \
# 0                    Yes                           Yes            Yes
# 1                    Yes                            No            Yes
# 2                    Yes                            No            Yes
# 3                     No                           Yes             No
# 4                    Yes                            No             No
# 5                     No                           Yes            Yes
# 6                    Yes                            No             No
# 7                    Yes                            No             No
# 8                    Yes                           Yes             No
# 9                     No                           Yes             No
#
#            complaint_status                  feedback churn_risk_score
# 0  No Information Available              Poor Website                1
# 1  No Information Available     Poor Customer Service                1
# 2  No Information Available              Too many ads                0
# 3            Not Applicable              Too many ads                1
# 4            Not Applicable      Poor Product Quality                0
# 5                  Unsolved      Poor Product Quality                0
# 6            Not Applicable       No reason specified                1
# 7            Not Applicable       No reason specified                1
# 8            Not Applicable  Products always in Stock                0
# 9            Not Applicable              Too many ads                1
#
# [10 rows x 22 columns]

# %%
df.tail(10)
# Out:
#                 user_id  age gender region_category membership_category  \
# 37000  8a0fff47b7846031   25      F            Town       No Membership
# 37001  8832eec42dc0e347   38      M            Town   Silver Membership
# 37002  b9d9761f4d367c7a   49      F            City       No Membership
# 37003  a38816e7522f5f7b   42      F            Town    Basic Membership
# 37004  8968d0458164dda9   19      F            Town     Gold Membership
# 37005  924e9c06f0c73817   36      M            Town     Gold Membership
# 37006  90e22286ac0acf04   27      F            City     Gold Membership
# 37007  9329a6297407334a   20      M             NaN     Gold Membership
# 37008  a4403ddda8fcf9f3   38      F            City     Gold Membership
# 37009  93b5d0330d24fa15   36      M            Town     Gold Membership
#
#       joining_date joined_through_referral     preferred_offer_types  \
# 37000   2017-01-20                      No     Gift Vouchers/Coupons
# 37001   2016-09-19                     NaN  Credit/Debit Card Offers
# 37002   2017-12-12                     NaN            Without Offers
# 37003   2017-07-05                     Yes     Gift Vouchers/Coupons
# 37004   2016-07-17                     Yes            Without Offers
# 37005   2015-03-05                     NaN  Credit/Debit Card Offers
# 37006   2017-01-15                     Yes            Without Offers
# 37007   2015-07-11                     Yes            Without Offers
# 37008   2016-05-25                     Yes            Without Offers
# 37009   2016-10-18                     NaN            Without Offers
#
#       medium_of_operation internet_option  ... avg_time_spent  \
# 37000          Smartphone           Wi-Fi  ...     119.830000
# 37001          Smartphone           Wi-Fi  ...      34.790000
# 37002                Both           Wi-Fi  ...     499.510000
# 37003                Both           Wi-Fi  ...     529.580000
# 37004          Smartphone     Fiber_Optic  ...     119.960000
# 37005                 NaN     Fiber_Optic  ...     199.330000
# 37006             Desktop           Wi-Fi  ...     368.500000
# 37007                 NaN     Mobile_Data  ...     272.130000
# 37008             Desktop           Wi-Fi  ...      65.070000
# 37009                Both     Fiber_Optic  ...     972.776679
#
#        avg_transaction_value  avg_frequency_login_days  points_in_wallet  \
# 37000               13147.91                       0.0       1019.382051
# 37001               30820.83                      23.0        631.830000
# 37002               17110.71                      24.0        587.010000
# 37003               42964.11                      18.0        619.280000
# 37004               14218.43                       7.0        781.840000
# 37005               29455.29                       9.0        846.520000
# 37006               27038.47                       8.0        835.980000
# 37007               39305.35                      27.0        714.900000
# 37008               46108.73                       6.0        744.990000
# 37009               26905.49                      22.0        700.930000
#
#        used_special_discount  offer_application_preference past_complaint  \
# 37000                    Yes                            No            Yes
# 37001                    Yes                            No            Yes
# 37002                    Yes                            No             No
# 37003                    Yes                           Yes             No
# 37004                    Yes                            No             No
# 37005                    Yes                           Yes             No
# 37006                     No                           Yes             No
# 37007                    Yes                           Yes            Yes
# 37008                     No                           Yes             No
# 37009                    Yes                            No            Yes
#
#                complaint_status               feedback churn_risk_score
# 37000       Solved in Follow-up   Poor Product Quality                1
# 37001                  Unsolved  Poor Customer Service                1
# 37002            Not Applicable  Poor Customer Service                1
# 37003            Not Applicable   Poor Product Quality                1
# 37004            Not Applicable           Too many ads                0
# 37005            Not Applicable  User Friendly Website                0
# 37006            Not Applicable       Reasonable Price                0
# 37007                    Solved  Poor Customer Service                0
# 37008            Not Applicable           Poor Website                0
# 37009  No Information Available  Poor Customer Service                1
#
# [10 rows x 22 columns]

# %% [markdown]
# # Exploration Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37010 entries, 0 to 37009
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   user_id                       37010 non-null  object
#  1   age                           37010 non-null  int64
#  2   gender                        36951 non-null  object
#  3   region_category               31579 non-null  object
#  4   membership_category           37010 non-null  object
#  5   joining_date                  37010 non-null  object
#  6   joined_through_referral       31568 non-null  object
#  7   preferred_offer_types         36722 non-null  object
#  8   medium_of_operation           31615 non-null  object
#  9   internet_option               37010 non-null  object
#  10  last_visit_time               37010 non-null  object
#  11  days_since_last_login         37010 non-null  int64
#  12  avg_time_spent                37010 non-null  float64
#  13  avg_transaction_value         37010 non-null  float64
#  14  avg_frequency_login_days      37010 non-null  float64
#  15  points_in_wallet              37010 non-null  float64
#  16  used_special_discount         37010 non-null  object
#  17  offer_application_preference  37010 non-null  object
#  18  past_complaint                37010 non-null  object
#  19  complaint_status              37010 non-null  object
#  20  feedback                      37010 non-null  object
#  21  churn_risk_score              37010 non-null  int64
# dtypes: float64(4), int64(3), object(15)
# memory usage: 6.2+ MB

# %%
df.describe()
# Out:
#                 age  days_since_last_login  avg_time_spent  \
# count  37010.000000           37010.000000    37010.000000
# mean      37.120697             -41.943502      279.201356
# std       15.866834             228.875324      330.017336
# min       10.000000            -999.000000        0.000000
# 25%       23.000000               8.000000       60.122500
# 50%       37.000000              12.000000      161.770000
# 75%       51.000000              16.000000      356.525000
# max       64.000000              26.000000     3235.578521
#
#        avg_transaction_value  avg_frequency_login_days  points_in_wallet  \
# count           37010.000000              37010.000000      37010.000000
# mean            29272.430216                 14.659540        623.590885
# std             19445.963492                  9.478756        270.218956
# min               800.460000                  0.000000          0.000000
# 25%             14177.835000                  7.000000        574.220000
# 50%             27554.485000                 14.000000        680.400000
# 75%             40858.672500                 22.000000        756.990000
# max             99914.050000                 73.061995       2069.069761
#
#        churn_risk_score
# count      37010.000000
# mean           0.540881
# std            0.498333
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            1.000000
# max            1.000000

# %%
df.isnull().sum()
# Out:
# user_id                            0
# age                                0
# gender                            59
# region_category                 5431
# membership_category                0
# joining_date                       0
# joined_through_referral         5442
# preferred_offer_types            288
# medium_of_operation             5395
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                   0
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# churn_risk_score                   0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 37005    False
# 37006    False
# 37007    False
# 37008    False
# 37009    False
# Length: 37010, dtype: bool

# %%
df.hist(bins=20, figsize=(15, 10))
plt.show()

# %%
for column in df.columns:
    print(f"Number of unique values in {column}: {df[column].nunique()}")
# Out:
# Number of unique values in user_id: 36992
# Number of unique values in age: 55
# Number of unique values in gender: 2
# Number of unique values in region_category: 3
# Number of unique values in membership_category: 6
# Number of unique values in joining_date: 1096
# Number of unique values in joined_through_referral: 2
# Number of unique values in preferred_offer_types: 3
# Number of unique values in medium_of_operation: 3
# Number of unique values in internet_option: 3
# Number of unique values in last_visit_time: 30101
# Number of unique values in days_since_last_login: 27
# Number of unique values in avg_time_spent: 24243
# Number of unique values in avg_transaction_value: 36894
# Number of unique values in avg_frequency_login_days: 971
# Number of unique values in points_in_wallet: 23564
# Number of unique values in used_special_discount: 2
# Number of unique values in offer_application_preference: 2
# Number of unique values in past_complaint: 2
# Number of unique values in complaint_status: 5
# Number of unique values in feedback: 9
# Number of unique values in churn_risk_score: 2

# %%
plt.hist(df['age'], bins=10)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# jumlah sebaran usia pada dataset

# %%
sns.countplot(data=df, x='churn_risk_score')
plt.show()

# %% [markdown]
# jumlah customer yang berhenti berlangganan

# %%
plt.scatter(df['avg_time_spent'], df['avg_transaction_value'], c=df['churn_risk_score'])
plt.xlabel('Average time spent')
plt.ylabel('Average transaction value')
plt.colorbar()
plt.show()

# %%
sns.boxplot(data=df, x='churn_risk_score', y='points_in_wallet')
plt.show()

# %% [markdown]
# sebaran data churn risk score berdasarkan point in wallet

# %%
sns.boxplot(data=df, x='churn_risk_score', y='age')
plt.show()

# %% [markdown]
# sebaran data churn risk score berdasarkan usia

# %%
sns.boxplot(data=df, x='churn_risk_score', y='avg_frequency_login_days')
plt.show()

# %% [markdown]
# sebaran data churn risk score berdasarkan rata-rata login harian

# %%
sns.countplot(data=df, x='region_category')
plt.show()

# %% [markdown]
# jumlah masing-masing kategori region

# %%
sns.countplot(data=df, x='membership_category')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# sebaran jumlah data kategori membership customer

# %% [markdown]
# # Feature Engineering

# %%
num_col = ['age','days_since_last_login','avg_time_spent','avg_transaction_value','avg_frequency_login_days']
cat_col_ohe = ['region_category','preferred_offer_types','medium_of_operation','internet_option','complaint_status','feedback']
cat_col_ord = ['gender','membership_category','joined_through_referral','used_special_discount','offer_application_preference','past_complaint']

# %%
fitur= df.drop('churn_risk_score',axis=1)
target= df['churn_risk_score']

# %%
x_train_full, x_test, y_train_full, y_test= train_test_split(
    fitur, target, test_size= 0.2, stratify=target)

# %%
x_train_full, x_test,  y_train_full, y_test = train_test_split(fitur,
                                                                target,
                                                                shuffle=True, test_size=0.2,
                                                                stratify= target
                                                                )

x_train, x_val, y_train, y_val = train_test_split(x_train_full,
                                                   y_train_full,
                                                   shuffle=True, test_size=0.2, stratify= y_train_full)

# %%
x_train.skew()
# Out:
# <ipython-input-87-6ed0439853c6>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   x_train.skew()
# age                         0.000570
# days_since_last_login      -3.961540
# avg_time_spent              2.253035
# avg_transaction_value       1.005827
# avg_frequency_login_days    0.380696
# points_in_wallet           -0.767203
# dtype: float64

# %%
num_transformer = Pipeline([
        ('outlier', Winsorizer(capping_method='gaussian', tail='both', fold=3)),
        ('scaler', StandardScaler())
    ])
num_ss = num_transformer.fit_transform(x_train[['age','avg_frequency_login_days']])

# %%
num_transformer2 = Pipeline([
        ('outlier', Winsorizer(capping_method='iqr', tail='both', fold=1.5)),
        ('scaler', MinMaxScaler())
    ])
num_mm = num_transformer2.fit_transform(x_train[['points_in_wallet']])

# %%
num_transformer3 = Pipeline([
        ('outlier', Winsorizer(capping_method='iqr', tail='both', fold=3)),
        ('scaler', MinMaxScaler())
    ])
num_mm2 = num_transformer3.fit_transform(x_train[['avg_time_spent','avg_transaction_value', 'days_since_last_login']])

# %%
cat_transformer = Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('ord_enc', OrdinalEncoder(categories=[['M', 'F'], ['No Membership', 'Basic Membership', 'Silver Membership', 'Premium Membership', 'Gold Membership', 'Platinum Membership'], ['No', 'Yes'], ['No', 'Yes'], ['No', 'Yes'], ['No', 'Yes']]))
])

# %%
cat_transformer2= Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('ohe_enc', OneHotEncoder(sparse=False))
])

# %%
full_pipeline = ColumnTransformer([
        ("num1", num_transformer, ['age','avg_frequency_login_days']),
        ("num2", num_transformer2, ['points_in_wallet']),
        ("num3", num_transformer3, ['avg_time_spent','avg_transaction_value', 'days_since_last_login']),
        ("cat_ord", cat_transformer, ['gender', 'membership_category','joined_through_referral','used_special_discount','offer_application_preference','past_complaint']),
        ("cat_ohe", cat_transformer2, ['region_category','preferred_offer_types','medium_of_operation','internet_option','complaint_status','feedback']),
    ])

# %%
X_train= full_pipeline.fit_transform(x_train_full)
X_test= full_pipeline.transform(x_test)
X_val = full_pipeline.transform(x_val)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # Model Definition

# %%
X_train.shape[1:]
# Out:
# (38,)

# %%
X_train
# Out:
# array([[-0.06818671,  1.43423285,  1.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.44671343,  0.04026023,  0.59698038, ...,  0.        ,
#          0.        ,  1.        ],
#        [-1.20376685,  0.46917488,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 1.25665678,  1.11254686,  0.98065984, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.81504228,  1.21977552,  0.37930486, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.49960336, -1.56816971,  0.57489635, ...,  0.        ,
#          1.        ,  0.        ]])

# %% [markdown]
# # Model Training

# %%
ann = Sequential()
# ann.add(tf.keras.Input(shape=(X_train.shape[1:])))
ann.add(Dense(units=30, activation='relu',input_shape=(X_train.shape[1:])))
ann.add(Dense(units=1,activation='sigmoid')) #sesuaikan dengan target atau jumlah class

ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
callbacks1= [
    EarlyStopping(monitor='val_loss', patience= 3, restore_best_weights=True),
    ModelCheckpoint('model_best.hdf5', monitor='val_loss', save_best_only=True)
]

# %%
hidden1 = ann.layers[1]
hidden1.name
# Out:
# 'dense_43'

# %%
weights, biases = hidden1.get_weights()
# weights

# %%
ann.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_42 (Dense)            (None, 30)                1170
#
#  dense_43 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 1,201
# Trainable params: 1,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(ann, show_shapes=True)

# %%
X_train.shape
# Out:
# (29608, 38)

# %% [markdown]
# # Model Sequential

# %%
# Set random seed
tf.random.set_seed(42)

# 1. Create the model 
model = tf.keras.Sequential([
  tf.keras.layers.Dense(100), # add 100 dense neurons
  tf.keras.layers.Dense(10), # add another layer with 10 neurons
  tf.keras.layers.Dense(1)
])

# 2. Compile the model
model.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Adam(), # use Adam
                metrics=['accuracy'])

# 3. Fit the model
history = model.fit(X_train, y_train_full, epochs=50, verbose=1, batch_size=32, validation_data=(X_val,y_val)) # fit for 50 passes of the data
# Out:
# Epoch 1/50
# 926/926 [==============================] - 5s 4ms/step - loss: 2.8671 - accuracy: 0.7657 - val_loss: 2.5606 - val_accuracy: 0.8043
# Epoch 2/50
# 926/926 [==============================] - 4s 5ms/step - loss: 2.4113 - accuracy: 0.8188 - val_loss: 3.1908 - val_accuracy: 0.7644
# Epoch 3/50
# 926/926 [==============================] - 5s 5ms/step - loss: 2.5410 - accuracy: 0.8101 - val_loss: 2.8651 - val_accuracy: 0.7866
# Epoch 4/50
# 926/926 [==============================] - 6s 6ms/step - loss: 2.5162 - accuracy: 0.8153 - val_loss: 2.1168 - val_accuracy: 0.8435
# Epoch 5/50
# 926/926 [==============================] - 6s 6ms/step - loss: 2.1912 - accuracy: 0.8383 - val_loss: 2.1007 - val_accuracy: 0.8479
# Epoch 6/50
# 926/926 [==============================] - 6s 6ms/step - loss: 2.5635 - accuracy: 0.8120 - val_loss: 2.6214 - val_accuracy: 0.8124
# Epoch 7/50
# 926/926 [==============================] - 7s 7ms/step - loss: 2.2556 - accuracy: 0.8384 - val_loss: 2.1849 - val_accuracy: 0.8452
# Epoch 8/50
# 926/926 [==============================] - 5s 5ms/step - loss: 2.2639 - accuracy: 0.8378 - val_loss: 2.0266 - val_accuracy: 0.8528
# Epoch 9/50
# 926/926 [==============================] - 3s 3ms/step - loss: 2.1803 - accuracy: 0.8411 - val_loss: 2.1296 - val_accuracy: 0.8428
# Epoch 10/50
# 926/926 [==============================] - 3s 4ms/step - loss: 2.1537 - accuracy: 0.8404 - val_loss: 2.0080 - val_accuracy: 0.8509
# Epoch 11/50
# 926/926 [==============================] - 4s 4ms/step - loss: 2.2498 - accuracy: 0.8338 - val_loss: 2.2617 - val_accuracy: 0.8370
# Epoch 12/50
# 926/926 [==============================] - 3s 3ms/step - loss: 2.2304 - accuracy: 0.8332 - val_loss: 2.5687 - val_accuracy: 0.8100
# Epoch 13/50
# 926/926 [==============================] - 3s 3ms/step - loss: 2.4010 - accuracy: 0.8233 - val_loss: 2.1645 - val_accuracy: 0.8364
# Epoch 14/50
# 926/926 [==============================] - 4s 4ms/step - loss: 2.2449 - accuracy: 0.8345 - val_loss: 2.1157 - val_accuracy: 0.8418
# Epoch 15/50
# 926/926 [==============================] - 3s 3ms/step - loss: 2.4036 - accuracy: 0.8240 - val_loss: 2.2868 - val_accuracy: 0.8320
# Epoch 16/50
# 926/926 [==============================] - 3s 3ms/step - loss: 2.1926 - accuracy: 0.8389 - val_loss: 2.0201 - val_accuracy: 0.8463
# Epoch 17/50
# 926/926 [==============================] - 3s 3ms/step - loss: 2.0706 - accuracy: 0.8451 - val_loss: 2.2490 - val_accuracy: 0.8370
# Epoch 18/50
# 926/926 [==============================] - 4s 4ms/step - loss: 2.2582 - accuracy: 0.8332 - val_loss: 2.7585 - val_accuracy: 0.8007
# Epoch 19/50
# 926/926 [==============================] - 3s 3ms/step - loss: 2.4577 - accuracy: 0.8174 - val_loss: 2.2501 - val_accuracy: 0.8269
# Epoch 20/50
# 926/926 [==============================] - 3s 3ms/step - loss: 2.2476 - accuracy: 0.8270 - val_loss: 2.0419 - val_accuracy: 0.8386
# Epoch 21/50
# 926/926 [==============================] - 3s 4ms/step - loss: 2.0662 - accuracy: 0.8361 - val_loss: 1.8471 - val_accuracy: 0.8479
# Epoch 22/50
# 926/926 [==============================] - 4s 4ms/step - loss: 2.4021 - accuracy: 0.8077 - val_loss: 2.1264 - val_accuracy: 0.8288
# Epoch 23/50
# 926/926 [==============================] - 3s 3ms/step - loss: 2.0796 - accuracy: 0.8288 - val_loss: 1.8776 - val_accuracy: 0.8394
# Epoch 24/50
# 926/926 [==============================] - 3s 3ms/step - loss: 1.7534 - accuracy: 0.8418 - val_loss: 1.4787 - val_accuracy: 0.8484
# Epoch 25/50
# 926/926 [==============================] - 4s 5ms/step - loss: 1.5469 - accuracy: 0.8448 - val_loss: 1.3473 - val_accuracy: 0.8435
# Epoch 26/50
# 926/926 [==============================] - 3s 4ms/step - loss: 1.1304 - accuracy: 0.8241 - val_loss: 0.4497 - val_accuracy: 0.8188
# Epoch 27/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4086 - accuracy: 0.8261 - val_loss: 0.4175 - val_accuracy: 0.8296
# Epoch 28/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4402 - accuracy: 0.8095 - val_loss: 0.4043 - val_accuracy: 0.8242
# Epoch 29/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4089 - accuracy: 0.8290 - val_loss: 0.3908 - val_accuracy: 0.8315
# Epoch 30/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4070 - accuracy: 0.8342 - val_loss: 0.3966 - val_accuracy: 0.8313
# Epoch 31/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3998 - accuracy: 0.8331 - val_loss: 0.3887 - val_accuracy: 0.8396
# Epoch 32/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4204 - accuracy: 0.8189 - val_loss: 0.3920 - val_accuracy: 0.8197
# Epoch 33/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4072 - accuracy: 0.8278 - val_loss: 0.3834 - val_accuracy: 0.8357
# Epoch 34/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4056 - accuracy: 0.8322 - val_loss: 0.3856 - val_accuracy: 0.8340
# Epoch 35/50
# 926/926 [==============================] - 5s 6ms/step - loss: 0.4235 - accuracy: 0.8124 - val_loss: 0.3895 - val_accuracy: 0.8279
# Epoch 36/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4045 - accuracy: 0.8326 - val_loss: 0.3865 - val_accuracy: 0.8343
# Epoch 37/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4215 - accuracy: 0.8171 - val_loss: 0.3937 - val_accuracy: 0.8200
# Epoch 38/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4063 - accuracy: 0.8290 - val_loss: 0.3889 - val_accuracy: 0.8370
# Epoch 39/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3983 - accuracy: 0.8324 - val_loss: 0.3894 - val_accuracy: 0.8342
# Epoch 40/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.3977 - accuracy: 0.8300 - val_loss: 0.4005 - val_accuracy: 0.8340
# Epoch 41/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4046 - accuracy: 0.8331 - val_loss: 0.3896 - val_accuracy: 0.8322
# Epoch 42/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4087 - accuracy: 0.8312 - val_loss: 0.3812 - val_accuracy: 0.8362
# Epoch 43/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4050 - accuracy: 0.8324 - val_loss: 0.3614 - val_accuracy: 0.8406
# Epoch 44/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4007 - accuracy: 0.8318 - val_loss: 0.3862 - val_accuracy: 0.8553
# Epoch 45/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4092 - accuracy: 0.8291 - val_loss: 0.3858 - val_accuracy: 0.8327
# Epoch 46/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4041 - accuracy: 0.8265 - val_loss: 0.3895 - val_accuracy: 0.8342
# Epoch 47/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4389 - accuracy: 0.7996 - val_loss: 0.4084 - val_accuracy: 0.8212
# Epoch 48/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4084 - accuracy: 0.8246 - val_loss: 0.3941 - val_accuracy: 0.8360
# Epoch 49/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4005 - accuracy: 0.8289 - val_loss: 0.3894 - val_accuracy: 0.8200
# Epoch 50/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3894 - accuracy: 0.8311 - val_loss: 0.3744 - val_accuracy: 0.8386

# %%
fig,ax= plt.subplots(1,2 , figsize=(30,10))

plt.subplot(1,2,1)
plt.title('Training and validation Accuracy', fontsize=12)
plt.plot(history.history['accuracy'], label='Training Acc')
plt.plot(history.history['val_accuracy'], label='Validation Acc')
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid(linestyle='--')

plt.subplot(1,2,2)
plt.title('Training and validation Loss', fontsize=12)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.ylabel('loss', fontsize=12)
plt.legend()
plt.grid(linestyle='--')
plt.show()

# %%
# Set random seed
tf.random.set_seed(42)

# 1. Create the model 
model_2 = tf.keras.Sequential([
  tf.keras.layers.Dense(100), # add 100 dense neurons
  tf.keras.layers.Dense(10), # add another layer with 10 neurons
  tf.keras.layers.Dense(1)
])

# 2. Compile the model
model_2.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Adamax(learning_rate= 0.01), # use AdaMax
                metrics=['accuracy'])

# 3. Fit the model
history = model_2.fit (X_train, y_train_full, epochs=50, verbose=1, batch_size=32, validation_data=(X_val,y_val)) # fit for 50 passes of the data
# Out:
# Epoch 1/50
# 926/926 [==============================] - 6s 4ms/step - loss: 1.9530 - accuracy: 0.8381 - val_loss: 1.6702 - val_accuracy: 0.8446
# Epoch 2/50
# 926/926 [==============================] - 4s 4ms/step - loss: 1.5089 - accuracy: 0.8471 - val_loss: 1.3145 - val_accuracy: 0.8514
# Epoch 3/50
# 926/926 [==============================] - 3s 3ms/step - loss: 1.3534 - accuracy: 0.8513 - val_loss: 1.3106 - val_accuracy: 0.8580
# Epoch 4/50
# 926/926 [==============================] - 3s 3ms/step - loss: 1.4943 - accuracy: 0.8480 - val_loss: 1.3835 - val_accuracy: 0.8538
# Epoch 5/50
# 926/926 [==============================] - 3s 3ms/step - loss: 1.4063 - accuracy: 0.8472 - val_loss: 1.3130 - val_accuracy: 0.8529
# Epoch 6/50
# 926/926 [==============================] - 4s 4ms/step - loss: 1.3512 - accuracy: 0.8518 - val_loss: 1.3094 - val_accuracy: 0.8646
# Epoch 7/50
# 926/926 [==============================] - 3s 4ms/step - loss: 1.3512 - accuracy: 0.8532 - val_loss: 1.3099 - val_accuracy: 0.8615
# Epoch 8/50
# 926/926 [==============================] - 4s 4ms/step - loss: 1.3489 - accuracy: 0.8530 - val_loss: 1.3095 - val_accuracy: 0.8644
# Epoch 9/50
# 926/926 [==============================] - 4s 4ms/step - loss: 1.3504 - accuracy: 0.8534 - val_loss: 1.3238 - val_accuracy: 0.8516
# Epoch 10/50
# 926/926 [==============================] - 3s 3ms/step - loss: 1.3520 - accuracy: 0.8542 - val_loss: 1.3079 - val_accuracy: 0.8568
# Epoch 11/50
# 926/926 [==============================] - 3s 3ms/step - loss: 1.3492 - accuracy: 0.8521 - val_loss: 1.3084 - val_accuracy: 0.8590
# Epoch 12/50
# 926/926 [==============================] - 3s 3ms/step - loss: 1.3490 - accuracy: 0.8530 - val_loss: 1.3135 - val_accuracy: 0.8533
# Epoch 13/50
# 926/926 [==============================] - 4s 4ms/step - loss: 1.3463 - accuracy: 0.8523 - val_loss: 0.8304 - val_accuracy: 0.8289
# Epoch 14/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4386 - accuracy: 0.8209 - val_loss: 0.3904 - val_accuracy: 0.8229
# Epoch 15/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4043 - accuracy: 0.8296 - val_loss: 0.3866 - val_accuracy: 0.8386
# Epoch 16/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4099 - accuracy: 0.8277 - val_loss: 0.3939 - val_accuracy: 0.8325
# Epoch 17/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4063 - accuracy: 0.8272 - val_loss: 0.3844 - val_accuracy: 0.8399
# Epoch 18/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4064 - accuracy: 0.8281 - val_loss: 0.3835 - val_accuracy: 0.8286
# Epoch 19/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4100 - accuracy: 0.8302 - val_loss: 0.3910 - val_accuracy: 0.8340
# Epoch 20/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4042 - accuracy: 0.8277 - val_loss: 0.3923 - val_accuracy: 0.8249
# Epoch 21/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3983 - accuracy: 0.8307 - val_loss: 0.3876 - val_accuracy: 0.8401
# Epoch 22/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4121 - accuracy: 0.8309 - val_loss: 0.4139 - val_accuracy: 0.8109
# Epoch 23/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4159 - accuracy: 0.8280 - val_loss: 0.3808 - val_accuracy: 0.8350
# Epoch 24/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3993 - accuracy: 0.8305 - val_loss: 0.3822 - val_accuracy: 0.8370
# Epoch 25/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.3966 - accuracy: 0.8310 - val_loss: 0.3837 - val_accuracy: 0.8306
# Epoch 26/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4056 - accuracy: 0.8326 - val_loss: 0.3842 - val_accuracy: 0.8386
# Epoch 27/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4037 - accuracy: 0.8311 - val_loss: 0.3754 - val_accuracy: 0.8362
# Epoch 28/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4082 - accuracy: 0.8314 - val_loss: 0.3882 - val_accuracy: 0.8288
# Epoch 29/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4183 - accuracy: 0.8233 - val_loss: 0.3939 - val_accuracy: 0.8235
# Epoch 30/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.3950 - accuracy: 0.8302 - val_loss: 0.3830 - val_accuracy: 0.8382
# Epoch 31/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.3891 - accuracy: 0.8320 - val_loss: 0.3790 - val_accuracy: 0.8403
# Epoch 32/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4062 - accuracy: 0.8329 - val_loss: 0.3896 - val_accuracy: 0.8350
# Epoch 33/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4051 - accuracy: 0.8320 - val_loss: 0.3704 - val_accuracy: 0.8479
# Epoch 34/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4039 - accuracy: 0.8323 - val_loss: 0.3947 - val_accuracy: 0.8328
# Epoch 35/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4034 - accuracy: 0.8335 - val_loss: 0.3763 - val_accuracy: 0.8355
# Epoch 36/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.3891 - accuracy: 0.8312 - val_loss: 0.3873 - val_accuracy: 0.8289
# Epoch 37/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.3935 - accuracy: 0.8351 - val_loss: 0.3915 - val_accuracy: 0.8338
# Epoch 38/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.3999 - accuracy: 0.8319 - val_loss: 0.3649 - val_accuracy: 0.8479
# Epoch 39/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3876 - accuracy: 0.8325 - val_loss: 0.3833 - val_accuracy: 0.8369
# Epoch 40/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.3955 - accuracy: 0.8336 - val_loss: 0.3934 - val_accuracy: 0.8333
# Epoch 41/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4069 - accuracy: 0.8317 - val_loss: 0.3837 - val_accuracy: 0.8305
# Epoch 42/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4026 - accuracy: 0.8306 - val_loss: 0.3819 - val_accuracy: 0.8533
# Epoch 43/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3984 - accuracy: 0.8348 - val_loss: 0.3633 - val_accuracy: 0.8452
# Epoch 44/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4055 - accuracy: 0.8324 - val_loss: 0.3767 - val_accuracy: 0.8408
# Epoch 45/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4058 - accuracy: 0.8326 - val_loss: 0.3970 - val_accuracy: 0.8289
# Epoch 46/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.4005 - accuracy: 0.8316 - val_loss: 0.3891 - val_accuracy: 0.8367
# Epoch 47/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4076 - accuracy: 0.8320 - val_loss: 0.3805 - val_accuracy: 0.8414
# Epoch 48/50
# 926/926 [==============================] - 3s 3ms/step - loss: 0.4056 - accuracy: 0.8343 - val_loss: 0.3731 - val_accuracy: 0.8340
# Epoch 49/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3975 - accuracy: 0.8303 - val_loss: 0.3829 - val_accuracy: 0.8396
# Epoch 50/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.4069 - accuracy: 0.8316 - val_loss: 0.3857 - val_accuracy: 0.8438

# %%
fig,ax= plt.subplots(1,2 , figsize=(30,10))

plt.subplot(1,2,1)
plt.title('Training and validation Accuracy', fontsize=12)
plt.plot(history.history['accuracy'], label='Training Acc')
plt.plot(history.history['val_accuracy'], label='Validation Acc')
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid(linestyle='--')

plt.subplot(1,2,2)
plt.title('Training and validation Loss', fontsize=12)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.ylabel('loss', fontsize=12)
plt.legend()
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# # Model Sequential Improvement

# %%
# Set random seed
tf.random.set_seed(42)

# 1. Create the model 
model3 = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation='elu'), # add 100 dense neurons
  tf.keras.layers.Dense(50, activation='elu'),
  tf.keras.layers.Dense(10, activation='elu'), # add another layer with 10 neurons
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# 2. Compile the model
model3.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Nadam(learning_rate= 0.01), # use Nadam
                metrics=['accuracy'])

# 3. Fit the model
history = model3.fit(X_train, y_train_full, epochs=50, verbose=1, batch_size=32, validation_data=(X_val,y_val)) # fit for 100 passes of the data
# Out:
# Epoch 1/50
# 926/926 [==============================] - 74s 4ms/step - loss: 0.3361 - accuracy: 0.8473 - val_loss: 0.3121 - val_accuracy: 0.8612
# Epoch 2/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.3226 - accuracy: 0.8523 - val_loss: 0.3084 - val_accuracy: 0.8647
# Epoch 3/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.3205 - accuracy: 0.8535 - val_loss: 0.3065 - val_accuracy: 0.8654
# Epoch 4/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.3211 - accuracy: 0.8550 - val_loss: 0.3073 - val_accuracy: 0.8676
# Epoch 5/50
# 926/926 [==============================] - 7s 7ms/step - loss: 0.3156 - accuracy: 0.8658 - val_loss: 0.3038 - val_accuracy: 0.8707
# Epoch 6/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.3122 - accuracy: 0.8736 - val_loss: 0.2802 - val_accuracy: 0.8913
# Epoch 7/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2972 - accuracy: 0.8816 - val_loss: 0.3013 - val_accuracy: 0.8803
# Epoch 8/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2959 - accuracy: 0.8823 - val_loss: 0.2909 - val_accuracy: 0.8842
# Epoch 9/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2942 - accuracy: 0.8837 - val_loss: 0.2757 - val_accuracy: 0.8929
# Epoch 10/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2903 - accuracy: 0.8854 - val_loss: 0.2792 - val_accuracy: 0.8921
# Epoch 11/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2913 - accuracy: 0.8846 - val_loss: 0.2805 - val_accuracy: 0.8921
# Epoch 12/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2897 - accuracy: 0.8855 - val_loss: 0.2764 - val_accuracy: 0.8924
# Epoch 13/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2897 - accuracy: 0.8853 - val_loss: 0.2762 - val_accuracy: 0.8929
# Epoch 14/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2913 - accuracy: 0.8854 - val_loss: 0.2941 - val_accuracy: 0.8811
# Epoch 15/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2939 - accuracy: 0.8841 - val_loss: 0.2846 - val_accuracy: 0.8894
# Epoch 16/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2890 - accuracy: 0.8867 - val_loss: 0.2944 - val_accuracy: 0.8816
# Epoch 17/50
# 926/926 [==============================] - 6s 6ms/step - loss: 0.2869 - accuracy: 0.8885 - val_loss: 0.2906 - val_accuracy: 0.8884
# Epoch 18/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2877 - accuracy: 0.8879 - val_loss: 0.2688 - val_accuracy: 0.8982
# Epoch 19/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2858 - accuracy: 0.8895 - val_loss: 0.2709 - val_accuracy: 0.8985
# Epoch 20/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2865 - accuracy: 0.8889 - val_loss: 0.2690 - val_accuracy: 0.8975
# Epoch 21/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2844 - accuracy: 0.8896 - val_loss: 0.2750 - val_accuracy: 0.8951
# Epoch 22/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2828 - accuracy: 0.8908 - val_loss: 0.2674 - val_accuracy: 0.9004
# Epoch 23/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2825 - accuracy: 0.8911 - val_loss: 0.2699 - val_accuracy: 0.8980
# Epoch 24/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2811 - accuracy: 0.8917 - val_loss: 0.2690 - val_accuracy: 0.8977
# Epoch 25/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2809 - accuracy: 0.8928 - val_loss: 0.2667 - val_accuracy: 0.8980
# Epoch 26/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2797 - accuracy: 0.8929 - val_loss: 0.2625 - val_accuracy: 0.9016
# Epoch 27/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2799 - accuracy: 0.8925 - val_loss: 0.2832 - val_accuracy: 0.8860
# Epoch 28/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2784 - accuracy: 0.8940 - val_loss: 0.2628 - val_accuracy: 0.9000
# Epoch 29/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2789 - accuracy: 0.8935 - val_loss: 0.2633 - val_accuracy: 0.9022
# Epoch 30/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2769 - accuracy: 0.8943 - val_loss: 0.2584 - val_accuracy: 0.9037
# Epoch 31/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2753 - accuracy: 0.8952 - val_loss: 0.2582 - val_accuracy: 0.9048
# Epoch 32/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2742 - accuracy: 0.8964 - val_loss: 0.2557 - val_accuracy: 0.9056
# Epoch 33/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2739 - accuracy: 0.8964 - val_loss: 0.2608 - val_accuracy: 0.9071
# Epoch 34/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2729 - accuracy: 0.8973 - val_loss: 0.2628 - val_accuracy: 0.9005
# Epoch 35/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2727 - accuracy: 0.8966 - val_loss: 0.2524 - val_accuracy: 0.9065
# Epoch 36/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2780 - accuracy: 0.8957 - val_loss: 0.2635 - val_accuracy: 0.9012
# Epoch 37/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2692 - accuracy: 0.8984 - val_loss: 0.2580 - val_accuracy: 0.9043
# Epoch 38/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2694 - accuracy: 0.8982 - val_loss: 0.2514 - val_accuracy: 0.9073
# Epoch 39/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2706 - accuracy: 0.8979 - val_loss: 0.2522 - val_accuracy: 0.9080
# Epoch 40/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2706 - accuracy: 0.8985 - val_loss: 0.2634 - val_accuracy: 0.9002
# Epoch 41/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2680 - accuracy: 0.8989 - val_loss: 0.2532 - val_accuracy: 0.9070
# Epoch 42/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2674 - accuracy: 0.9001 - val_loss: 0.2545 - val_accuracy: 0.9085
# Epoch 43/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2660 - accuracy: 0.9005 - val_loss: 0.2565 - val_accuracy: 0.9058
# Epoch 44/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2675 - accuracy: 0.8998 - val_loss: 0.2515 - val_accuracy: 0.9097
# Epoch 45/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2729 - accuracy: 0.8994 - val_loss: 0.2558 - val_accuracy: 0.9054
# Epoch 46/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2682 - accuracy: 0.8990 - val_loss: 0.2485 - val_accuracy: 0.9085
# Epoch 47/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2638 - accuracy: 0.9016 - val_loss: 0.2497 - val_accuracy: 0.9083
# Epoch 48/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2648 - accuracy: 0.9006 - val_loss: 0.2624 - val_accuracy: 0.9041
# Epoch 49/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2654 - accuracy: 0.9010 - val_loss: 0.2546 - val_accuracy: 0.9043
# Epoch 50/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2651 - accuracy: 0.9009 - val_loss: 0.2561 - val_accuracy: 0.9068

# %% [markdown]
# # Model Evaluatiuon

# %%
fig,ax= plt.subplots(1,2 , figsize=(30,10))

plt.subplot(1,2,1)
plt.title('Training and validation Accuracy', fontsize=12)
plt.plot(history.history['accuracy'], label='Training Acc')
plt.plot(history.history['val_accuracy'], label='Validation Acc')
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid(linestyle='--')

plt.subplot(1,2,2)
plt.title('Training and validation Loss', fontsize=12)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.ylabel('loss', fontsize=12)
plt.legend()
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# # Model Functional API

# %%
# functional API
input_layer= tf.keras.Input(shape=(X_train.shape[1:]),name='input_layer')

hidden_1= Dense(30, activation='relu', name='hidden_1')(input_layer)
hidden_2= Dense(30, activation='relu', name='hidden_2')(hidden_1)
hidden_3= Dense(10, activation='relu', name='hidden_3')(hidden_2)
concat= tf.keras.layers.concatenate([input_layer,hidden_3])

output_layer= Dense(1, activation='sigmoid', name='output_layer')(concat)

model_func= Model(inputs=input_layer,
                  outputs=output_layer)

model_func.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
tf.keras.utils.plot_model(model_func, show_shapes=True)

# %%
callbacks2= [
    EarlyStopping(monitor='val_loss', patience= 3, restore_best_weights=True),
    ModelCheckpoint('model_best_func.hdf5', monitor='val_loss', save_best_only=True)
]

# %%
# Set random seed
tf.random.set_seed(42)

# 1. Create the model 
model4 = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation='relu'), # add 100 dense neurons
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(10, activation='relu'), # add another layer with 10 neurons
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# 2. Compile the model
model4.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Nadam(learning_rate= 0.01), # use Nadam
                metrics=['accuracy'])

# 3. Fit the model
history = model4.fit(X_train, y_train_full, epochs=50, verbose=1, batch_size=32, validation_data=(X_val,y_val)) # fit for 50 passes of the data
# Out:
# Epoch 1/50
# 926/926 [==============================] - 6s 5ms/step - loss: 0.3190 - accuracy: 0.8470 - val_loss: 0.2620 - val_accuracy: 0.8453
# Epoch 2/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2677 - accuracy: 0.8543 - val_loss: 0.2663 - val_accuracy: 0.8406
# Epoch 3/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2629 - accuracy: 0.8515 - val_loss: 0.2495 - val_accuracy: 0.8637
# Epoch 4/50
# 926/926 [==============================] - 6s 7ms/step - loss: 0.2639 - accuracy: 0.8541 - val_loss: 0.2595 - val_accuracy: 0.8664
# Epoch 5/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2589 - accuracy: 0.8578 - val_loss: 0.2450 - val_accuracy: 0.8761
# Epoch 6/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2546 - accuracy: 0.8663 - val_loss: 0.2421 - val_accuracy: 0.8717
# Epoch 7/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2454 - accuracy: 0.8742 - val_loss: 0.2325 - val_accuracy: 0.8804
# Epoch 8/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2367 - accuracy: 0.8789 - val_loss: 0.2238 - val_accuracy: 0.8850
# Epoch 9/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2333 - accuracy: 0.8816 - val_loss: 0.2164 - val_accuracy: 0.8835
# Epoch 10/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2319 - accuracy: 0.8812 - val_loss: 0.2423 - val_accuracy: 0.8707
# Epoch 11/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2293 - accuracy: 0.8800 - val_loss: 0.2122 - val_accuracy: 0.8838
# Epoch 12/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2269 - accuracy: 0.8804 - val_loss: 0.2107 - val_accuracy: 0.8837
# Epoch 13/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2268 - accuracy: 0.8808 - val_loss: 0.2147 - val_accuracy: 0.8882
# Epoch 14/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2261 - accuracy: 0.8822 - val_loss: 0.2230 - val_accuracy: 0.8867
# Epoch 15/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2210 - accuracy: 0.8845 - val_loss: 0.2112 - val_accuracy: 0.8820
# Epoch 16/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2229 - accuracy: 0.8819 - val_loss: 0.2278 - val_accuracy: 0.8794
# Epoch 17/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2186 - accuracy: 0.8816 - val_loss: 0.2170 - val_accuracy: 0.8870
# Epoch 18/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2182 - accuracy: 0.8824 - val_loss: 0.2072 - val_accuracy: 0.8815
# Epoch 19/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2166 - accuracy: 0.8848 - val_loss: 0.2126 - val_accuracy: 0.8848
# Epoch 20/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2158 - accuracy: 0.8847 - val_loss: 0.2229 - val_accuracy: 0.8759
# Epoch 21/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2145 - accuracy: 0.8840 - val_loss: 0.2110 - val_accuracy: 0.8904
# Epoch 22/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2140 - accuracy: 0.8832 - val_loss: 0.2028 - val_accuracy: 0.8899
# Epoch 23/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2172 - accuracy: 0.8834 - val_loss: 0.2164 - val_accuracy: 0.8870
# Epoch 24/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2115 - accuracy: 0.8834 - val_loss: 0.1995 - val_accuracy: 0.8886
# Epoch 25/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2100 - accuracy: 0.8841 - val_loss: 0.2040 - val_accuracy: 0.8880
# Epoch 26/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2127 - accuracy: 0.8844 - val_loss: 0.1960 - val_accuracy: 0.8924
# Epoch 27/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2074 - accuracy: 0.8850 - val_loss: 0.1966 - val_accuracy: 0.8934
# Epoch 28/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2225 - accuracy: 0.8843 - val_loss: 0.2020 - val_accuracy: 0.8899
# Epoch 29/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2120 - accuracy: 0.8854 - val_loss: 0.1991 - val_accuracy: 0.8902
# Epoch 30/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2103 - accuracy: 0.8899 - val_loss: 0.1959 - val_accuracy: 0.9071
# Epoch 31/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2018 - accuracy: 0.9030 - val_loss: 0.1846 - val_accuracy: 0.9210
# Epoch 32/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1869 - accuracy: 0.9199 - val_loss: 0.1703 - val_accuracy: 0.9284
# Epoch 33/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1829 - accuracy: 0.9213 - val_loss: 0.1767 - val_accuracy: 0.9267
# Epoch 34/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1790 - accuracy: 0.9235 - val_loss: 0.1946 - val_accuracy: 0.9183
# Epoch 35/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1787 - accuracy: 0.9230 - val_loss: 0.1918 - val_accuracy: 0.9156
# Epoch 36/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1764 - accuracy: 0.9245 - val_loss: 0.1676 - val_accuracy: 0.9279
# Epoch 37/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1776 - accuracy: 0.9236 - val_loss: 0.1686 - val_accuracy: 0.9282
# Epoch 38/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1750 - accuracy: 0.9245 - val_loss: 0.1598 - val_accuracy: 0.9292
# Epoch 39/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1731 - accuracy: 0.9253 - val_loss: 0.1602 - val_accuracy: 0.9301
# Epoch 40/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1781 - accuracy: 0.9236 - val_loss: 0.1605 - val_accuracy: 0.9318
# Epoch 41/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1698 - accuracy: 0.9259 - val_loss: 0.1515 - val_accuracy: 0.9347
# Epoch 42/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.1707 - accuracy: 0.9262 - val_loss: 0.1661 - val_accuracy: 0.9289
# Epoch 43/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1682 - accuracy: 0.9266 - val_loss: 0.1596 - val_accuracy: 0.9336
# Epoch 44/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1708 - accuracy: 0.9265 - val_loss: 0.1663 - val_accuracy: 0.9264
# Epoch 45/50
# 926/926 [==============================] - 6s 7ms/step - loss: 0.1699 - accuracy: 0.9253 - val_loss: 0.1563 - val_accuracy: 0.9326
# Epoch 46/50
# 926/926 [==============================] - 5s 6ms/step - loss: 0.1675 - accuracy: 0.9278 - val_loss: 0.1632 - val_accuracy: 0.9265
# Epoch 47/50
# 926/926 [==============================] - 7s 8ms/step - loss: 0.1666 - accuracy: 0.9276 - val_loss: 0.1619 - val_accuracy: 0.9296
# Epoch 48/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.1652 - accuracy: 0.9279 - val_loss: 0.1482 - val_accuracy: 0.9360
# Epoch 49/50
# 926/926 [==============================] - 6s 6ms/step - loss: 0.1700 - accuracy: 0.9256 - val_loss: 0.1525 - val_accuracy: 0.9362
# Epoch 50/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.1666 - accuracy: 0.9278 - val_loss: 0.1812 - val_accuracy: 0.9232

# %%
fig,ax= plt.subplots(1,2 , figsize=(30,10))

plt.subplot(1,2,1)
plt.title('Training and validation Accuracy', fontsize=12)
plt.plot(history.history['accuracy'], label='Training Acc')
plt.plot(history.history['val_accuracy'], label='Validation Acc')
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid(linestyle='--')

plt.subplot(1,2,2)
plt.title('Training and validation Loss', fontsize=12)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.ylabel('loss', fontsize=12)
plt.legend()
plt.grid(linestyle='--')
plt.show()

# %%
# Set random seed
tf.random.set_seed(42)

# 1. Create the model 
model5 = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation='relu'), # add 100 dense neurons
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(10, activation='relu'), # add another layer with 10 neurons
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# 2. Compile the model
model5.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Adam(learning_rate= 0.01), # use Nadam
                metrics=['accuracy'])

# 3. Fit the model
history = model5.fit(X_train, y_train_full, epochs=50, verbose=1, batch_size=32, validation_data=(X_val,y_val)) # fit for 50 passes of the data
# Out:
# Epoch 1/50
# 926/926 [==============================] - 6s 4ms/step - loss: 0.3350 - accuracy: 0.8484 - val_loss: 0.2746 - val_accuracy: 0.8384
# Epoch 2/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2744 - accuracy: 0.8461 - val_loss: 0.2638 - val_accuracy: 0.8370
# Epoch 3/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2670 - accuracy: 0.8486 - val_loss: 0.2527 - val_accuracy: 0.8499
# Epoch 4/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2611 - accuracy: 0.8500 - val_loss: 0.2550 - val_accuracy: 0.8521
# Epoch 5/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2625 - accuracy: 0.8501 - val_loss: 0.2682 - val_accuracy: 0.8533
# Epoch 6/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2609 - accuracy: 0.8500 - val_loss: 0.2528 - val_accuracy: 0.8443
# Epoch 7/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2622 - accuracy: 0.8505 - val_loss: 0.2567 - val_accuracy: 0.8421
# Epoch 8/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2584 - accuracy: 0.8560 - val_loss: 0.2564 - val_accuracy: 0.8453
# Epoch 9/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2603 - accuracy: 0.8519 - val_loss: 0.2503 - val_accuracy: 0.8479
# Epoch 10/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2576 - accuracy: 0.8505 - val_loss: 0.2498 - val_accuracy: 0.8514
# Epoch 11/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2588 - accuracy: 0.8465 - val_loss: 0.2500 - val_accuracy: 0.8490
# Epoch 12/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2564 - accuracy: 0.8496 - val_loss: 0.2455 - val_accuracy: 0.8644
# Epoch 13/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2553 - accuracy: 0.8549 - val_loss: 0.2418 - val_accuracy: 0.8580
# Epoch 14/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2539 - accuracy: 0.8591 - val_loss: 0.2460 - val_accuracy: 0.8681
# Epoch 15/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2515 - accuracy: 0.8618 - val_loss: 0.2532 - val_accuracy: 0.8566
# Epoch 16/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2505 - accuracy: 0.8648 - val_loss: 0.2350 - val_accuracy: 0.8777
# Epoch 17/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2433 - accuracy: 0.8721 - val_loss: 0.2456 - val_accuracy: 0.8668
# Epoch 18/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2379 - accuracy: 0.8758 - val_loss: 0.2647 - val_accuracy: 0.8771
# Epoch 19/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2396 - accuracy: 0.8767 - val_loss: 0.2196 - val_accuracy: 0.8879
# Epoch 20/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2310 - accuracy: 0.8805 - val_loss: 0.2242 - val_accuracy: 0.8864
# Epoch 21/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2264 - accuracy: 0.8820 - val_loss: 0.2200 - val_accuracy: 0.8869
# Epoch 22/50
# 926/926 [==============================] - 6s 6ms/step - loss: 0.2262 - accuracy: 0.8817 - val_loss: 0.2125 - val_accuracy: 0.8858
# Epoch 23/50
# 926/926 [==============================] - 6s 6ms/step - loss: 0.2259 - accuracy: 0.8801 - val_loss: 0.2103 - val_accuracy: 0.8864
# Epoch 24/50
# 926/926 [==============================] - 5s 6ms/step - loss: 0.2270 - accuracy: 0.8847 - val_loss: 0.2065 - val_accuracy: 0.8934
# Epoch 25/50
# 926/926 [==============================] - 5s 6ms/step - loss: 0.2230 - accuracy: 0.8831 - val_loss: 0.2147 - val_accuracy: 0.8842
# Epoch 26/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2233 - accuracy: 0.8834 - val_loss: 0.2090 - val_accuracy: 0.8913
# Epoch 27/50
# 926/926 [==============================] - 6s 7ms/step - loss: 0.2176 - accuracy: 0.8866 - val_loss: 0.2078 - val_accuracy: 0.8889
# Epoch 28/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2194 - accuracy: 0.8851 - val_loss: 0.2090 - val_accuracy: 0.8891
# Epoch 29/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2183 - accuracy: 0.8825 - val_loss: 0.2235 - val_accuracy: 0.8853
# Epoch 30/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2175 - accuracy: 0.8835 - val_loss: 0.2049 - val_accuracy: 0.8830
# Epoch 31/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2226 - accuracy: 0.8818 - val_loss: 0.2076 - val_accuracy: 0.8891
# Epoch 32/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2171 - accuracy: 0.8841 - val_loss: 0.2094 - val_accuracy: 0.8853
# Epoch 33/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2162 - accuracy: 0.8846 - val_loss: 0.2125 - val_accuracy: 0.8892
# Epoch 34/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2116 - accuracy: 0.8844 - val_loss: 0.2143 - val_accuracy: 0.8813
# Epoch 35/50
# 926/926 [==============================] - 6s 7ms/step - loss: 0.2149 - accuracy: 0.8845 - val_loss: 0.1959 - val_accuracy: 0.8896
# Epoch 36/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2090 - accuracy: 0.8859 - val_loss: 0.2132 - val_accuracy: 0.8830
# Epoch 37/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2098 - accuracy: 0.8867 - val_loss: 0.2046 - val_accuracy: 0.8838
# Epoch 38/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2077 - accuracy: 0.8853 - val_loss: 0.1956 - val_accuracy: 0.8858
# Epoch 39/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2090 - accuracy: 0.8875 - val_loss: 0.1945 - val_accuracy: 0.8911
# Epoch 40/50
# 926/926 [==============================] - 4s 4ms/step - loss: 0.2105 - accuracy: 0.8877 - val_loss: 0.1972 - val_accuracy: 0.8924
# Epoch 41/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2078 - accuracy: 0.8868 - val_loss: 0.1951 - val_accuracy: 0.8848
# Epoch 42/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2073 - accuracy: 0.8861 - val_loss: 0.1968 - val_accuracy: 0.8931
# Epoch 43/50
# 926/926 [==============================] - 6s 6ms/step - loss: 0.2056 - accuracy: 0.8881 - val_loss: 0.1941 - val_accuracy: 0.8899
# Epoch 44/50
# 926/926 [==============================] - 4s 5ms/step - loss: 0.2064 - accuracy: 0.8877 - val_loss: 0.1926 - val_accuracy: 0.8940
# Epoch 45/50
# 926/926 [==============================] - 3s 4ms/step - loss: 0.2057 - accuracy: 0.8881 - val_loss: 0.1919 - val_accuracy: 0.8926
# Epoch 46/50
# 926/926 [==============================] - 6s 6ms/step - loss: 0.2048 - accuracy: 0.8880 - val_loss: 0.1983 - val_accuracy: 0.8928
# Epoch 47/50
# 926/926 [==============================] - 6s 6ms/step - loss: 0.2050 - accuracy: 0.8873 - val_loss: 0.1983 - val_accuracy: 0.8880
# Epoch 48/50
# 926/926 [==============================] - 6s 6ms/step - loss: 0.2021 - accuracy: 0.8870 - val_loss: 0.1905 - val_accuracy: 0.8906
# Epoch 49/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2035 - accuracy: 0.8875 - val_loss: 0.2081 - val_accuracy: 0.8904
# Epoch 50/50
# 926/926 [==============================] - 5s 5ms/step - loss: 0.2028 - accuracy: 0.8895 - val_loss: 0.1956 - val_accuracy: 0.8918

# %%
fig,ax= plt.subplots(1,2 , figsize=(30,10))

plt.subplot(1,2,1)
plt.title('Training and validation Accuracy', fontsize=12)
plt.plot(history.history['accuracy'], label='Training Acc')
plt.plot(history.history['val_accuracy'], label='Validation Acc')
plt.ylabel('Accuracy', fontsize=12)
plt.legend()
plt.grid(linestyle='--')

plt.subplot(1,2,2)
plt.title('Training and validation Loss', fontsize=12)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.ylabel('loss', fontsize=12)
plt.legend()
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# # Model Saving

# %%
joblib.dump(num_transformer,'num_transformer.pkl')
joblib.dump(num_transformer2,'num_transformer2.pkl')
joblib.dump(num_transformer3,'num_transformer3.pkl')
joblib.dump(cat_transformer,'cat_transformer.pkl')
joblib.dump(cat_transformer2,'cat_transformer2.pkl')
joblib.dump(full_pipeline,'full_pipeline.pkl')
# Out:
# ['full_pipeline.pkl']

# %% [markdown]
# # Model Analysis

# %% [markdown]
# Model Sequential pertama digunakan menggunakan optimizer Adam didapat accuraccy 82% dan val_accuracy 83% yang termasuk goodfit, setelah dilakukan improvement dengan penambahan activation elu dan sigmoid dengan optimizer Nadam lr: 0.01 didapatkan hasil accuracy 90% dan val _accuracynya juga 90%. Model Functional API Improvement 1 mengunakan activation relu dan sigmoid dengan optimizer Nadam lr: 0.01 didapatkan accuracy 92% dan val_accuracy 92% juga dan pada model improvement 2 menggunakan activation relu dan sigmoid dengan optimizer Adam lr: 0.01 didapatkan accuracy 88% dan val_accuracy 89%

# %% [markdown]
# # Overall Analysis

# %% [markdown]
# Model saya buat tidak menggunakan feature selection karena semua data yang ada pada dataset merupakan fitur yang penting dalam menunjang pembuatan model. model dengan hasil terbaik adalah model yang menggunakan activation relu dan sigmoid dengan optimizer Nadam lr:0.01 dengan accuracy 92% dan Val_accuracy 92%.
